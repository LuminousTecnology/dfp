# %% [markdown]
# <a href="https://colab.research.google.com/github/TitanTensei/dfp/blob/main/dfp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url_csv = 'https://github.com/msperlin/GetITRData_auxiliary/raw/master/InfoBovespaCompanies.csv'
infobovespacompanies = pd.read_csv(url_csv)

# %%
infobovespacompanies
# Out:
#                       name.company  id.company  ...     id.type type.fin.report
# 0             BANCO DO BRASIL S.A.        1023  ...  after 2011             dfp
# 1             BANCO DO BRASIL S.A.        1023  ...  after 2011             dfp
# 2             BANCO DO BRASIL S.A.        1023  ...  after 2011             dfp
# 3             BANCO DO BRASIL S.A.        1023  ...  after 2011             dfp
# 4             BANCO DO BRASIL S.A.        1023  ...  after 2011             dfp
# ...                            ...         ...  ...         ...             ...
# 49203  REFINARIA PET MANGUINHOS SA        9989  ...  after 2011             fca
# 49204  REFINARIA PET MANGUINHOS SA        9989  ...  after 2011             fca
# 49205  REFINARIA PET MANGUINHOS SA        9989  ...  after 2011             fca
# 49206  REFINARIA PET MANGUINHOS SA        9989  ...  after 2011             fca
# 49207  REFINARIA PET MANGUINHOS SA        9989  ...  after 2011             fca
#
# ...
