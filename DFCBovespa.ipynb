# %% [markdown]
# <a href="https://colab.research.google.com/github/TitanTensei/dfp/blob/master/DFCBovespa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab.data_table import DataTable
# !pip3 install wget

# %% [markdown]
# # **1 Download links da CVM**

# %%
# download das DFP da pagina da CVM
import wget
import os

# 2010 = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2010.zip'
# 2011 = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2011.zip'
# 2012 = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2012.zip'
# 2013 = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2013.zip'
# 2014 = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2014.zip'
# 2015 = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2015.zip'
# 2016 = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2016.zip'



urls = ['http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2017.zip',
        'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2018.zip',
        'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2019.zip',
        'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2020.zip']

path = '/content/drive/MyDrive/Bovespa/ZIP'

for url in urls:
    filename = path + '/' + os.path.basename(url) # get the full path of the file
    if os.path.exists(filename):
        os.remove(filename) # if exist, remove it directly
    wget.download(url, out=filename)

# %% [markdown]
# # **2 Unzip files**

# %%
# Unzip file
import os
import shutil
import zipfile

# Import os arquivos zip para dezipar
zip_filepath_2010 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2010.zip'
zip_filepath_2011 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2011.zip'
zip_filepath_2012 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2012.zip'
zip_filepath_2013 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2013.zip'
zip_filepath_2014 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2014.zip'
zip_filepath_2015 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2015.zip'
zip_filepath_2016 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2016.zip'
zip_filepath_2017 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2017.zip'
zip_filepath_2018 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2018.zip'
zip_filepath_2019 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2019.zip'
zip_filepath_2020 ='/content/drive/MyDrive/Bovespa/ZIP/dfp_cia_aberta_2020.zip'

# %%
# Unzip BPA
target_dir_BPA ='/content/drive/MyDrive/Bovespa/BPA'


with zipfile.ZipFile(zip_filepath_2010) as z:
    with z.open('dfp_cia_aberta_BPA_con_2010.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2010.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2011) as z:
    with z.open('dfp_cia_aberta_BPA_con_2011.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2011.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2012) as z:
    with z.open('dfp_cia_aberta_BPA_con_2012.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2012.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2013) as z:
    with z.open('dfp_cia_aberta_BPA_con_2013.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2013.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2014) as z:
    with z.open('dfp_cia_aberta_BPA_con_2014.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2014.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2015) as z:
    with z.open('dfp_cia_aberta_BPA_con_2015.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2015.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2016) as z:
    with z.open('dfp_cia_aberta_BPA_con_2016.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2016.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2017) as z:
    with z.open('dfp_cia_aberta_BPA_con_2017.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2017.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2018) as z:
    with z.open('dfp_cia_aberta_BPA_con_2018.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2018.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2019) as z:
    with z.open('dfp_cia_aberta_BPA_con_2019.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2019.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2020) as z:
    with z.open('dfp_cia_aberta_BPA_con_2020.csv') as zf, open(os.path.join(target_dir_BPA, os.path.basename('dfp_cia_aberta_BPA_con_2020.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

# %%
# Unzip BPP
target_dir_BPP ='/content/drive/MyDrive/Bovespa/BPP'


with zipfile.ZipFile(zip_filepath_2010) as z:
    with z.open('dfp_cia_aberta_BPP_con_2010.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2010.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2011) as z:
    with z.open('dfp_cia_aberta_BPP_con_2011.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2011.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2012) as z:
    with z.open('dfp_cia_aberta_BPP_con_2012.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2012.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2013) as z:
    with z.open('dfp_cia_aberta_BPP_con_2013.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2013.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2014) as z:
    with z.open('dfp_cia_aberta_BPP_con_2014.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2014.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2015) as z:
    with z.open('dfp_cia_aberta_BPP_con_2015.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2015.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2016) as z:
    with z.open('dfp_cia_aberta_BPP_con_2016.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2016.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2017) as z:
    with z.open('dfp_cia_aberta_BPP_con_2017.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2017.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2018) as z:
    with z.open('dfp_cia_aberta_BPP_con_2018.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2018.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2019) as z:
    with z.open('dfp_cia_aberta_BPP_con_2019.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2019.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2020) as z:
    with z.open('dfp_cia_aberta_BPP_con_2020.csv') as zf, open(os.path.join(target_dir_BPP, os.path.basename('dfp_cia_aberta_BPP_con_2020.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

# %%
# Unzip DFC
target_dir_DFC ='/content/drive/MyDrive/Bovespa/DFC'

with zipfile.ZipFile(zip_filepath_2010) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2010.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2010.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2011) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2011.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2011.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2012) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2012.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2012.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2013) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2013.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2013.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2014) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2014.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2014.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2015) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2015.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2015.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2016) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2016.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2016.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2017) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2017.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2017.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2018) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2018.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2018.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2019) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2019.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2019.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2020) as z:
    with z.open('dfp_cia_aberta_DFC_MI_con_2020.csv') as zf, open(os.path.join(target_dir_DFC, os.path.basename('dfp_cia_aberta_DFC_MI_con_2020.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

# %%
# Unzip DRE
target_dir_DRE ='/content/drive/MyDrive/Bovespa/DRE'


with zipfile.ZipFile(zip_filepath_2010) as z:
    with z.open('dfp_cia_aberta_DRE_con_2010.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2010.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2011) as z:
    with z.open('dfp_cia_aberta_DRE_con_2011.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2011.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2012) as z:
    with z.open('dfp_cia_aberta_DRE_con_2012.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2012.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2013) as z:
    with z.open('dfp_cia_aberta_DRE_con_2013.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2013.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2014) as z:
    with z.open('dfp_cia_aberta_DRE_con_2014.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2014.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2015) as z:
    with z.open('dfp_cia_aberta_DRE_con_2015.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2015.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2016) as z:
    with z.open('dfp_cia_aberta_DRE_con_2016.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2016.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2017) as z:
    with z.open('dfp_cia_aberta_DRE_con_2017.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2017.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2018) as z:
    with z.open('dfp_cia_aberta_DRE_con_2018.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2018.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2019) as z:
    with z.open('dfp_cia_aberta_DRE_con_2019.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2019.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

with zipfile.ZipFile(zip_filepath_2020) as z:
    with z.open('dfp_cia_aberta_DRE_con_2020.csv') as zf, open(os.path.join(target_dir_DRE, os.path.basename('dfp_cia_aberta_DRE_con_2020.csv')), 'wb') as f:
        shutil.copyfileobj(zf, f)

# %% [markdown]
# # **&&&&&&&&&&&&&&&&Complete DRE subs**

# %%
replace_value_bpa = {'ativo total' : 'ativo_total' , 
                      'ativo circulante' : 'ativo_circ' , 
                      'caixa e depositos bancarios' : 'caixa_equival' , 
                      'caixa e disponibilidade em bancos' : 'caixa_equival' , 
                      'caixa e disponibilidades em bancos' : 'caixa_equival' , 
                      'caixa e equivalentes de caixa' : 'caixa_equival' , 
                      'disponibilidades' : 'caixa_equival' , 
                      'disponibilidades e reservas no banco central do brasil' : 'caixa_equival' , 
                      'disponibilidades e saldos com o banco central' : 'caixa_equival' , 
                      'disponibilidades e saldos com o banco central do brasil' : 'caixa_equival' , 
                      'disponivel e saldos no banco central da republica argentina' : 'caixa_equival' , 
                      'aplicacoes financeiras' : 'aplicacoes_financ' , 
                      'aplicacoes no mercado aberto (antes da adocao do ifrs 9)' : 'aplicacoes_financ' , 
                      'contas especiais de garantia em bancos centrais' : 'aplicacoes_financ' , 
                      'depositos compulsorios no banco central' : 'aplicacoes_financ' , 
                      'depositos interfinanceiros' : 'aplicacoes_financ' , 
                      'emprestimos a instituicoes financeiras' : 'aplicacoes_financ' , 
                      'relacoes interfinanceiras' : 'aplicacoes_financ' , 
                      'reservas no banco central' : 'aplicacoes_financ' , 
                      'reservas no banco central e aplicacao no mercado aberto' : 'aplicacoes_financ' , 
                      'saldos em outras entidades financeiras' : 'aplicacoes_financ' , 
                      'contas a receber' : 'contas_receber' , 
                      'credito a instituicoes financeiras' : 'contas_receber' , 
                      'creditos a instituicoes financeiras' : 'contas_receber' , 
                      'estoques' : 'estoques' , 
                      'ativo nao circulante' : 'ativo_nao_circ' , 
                      'ativos financeiros' : 'ativo_nao_circ' , 
                      'ativo realizavel a longo prazo' : 'ativo_realizavel_longo_prazo' , 
                      'ativos financeiros avaliados a valor justo atraves do resultado' : 'ativo_realizavel_longo_prazo' , 
                      'investimentos' : 'investimentos' , 
                      'imobilizado' : 'imobilizado' , 
                      'intangivel' : 'intangivel' , 
                      'goodwill' : 'goodwill' , 
                      'goodwill  na aquisicao da satipel em 2009' : 'goodwill' , 
                      'goodwill na aquisicao da satipel em 2009' : 'goodwill' , 
                      'intangivel alocado' : 'goodwill' , 
                      'goodwill  na aquisicao ceramica monte carlo em 2008' : 'goodwill' , 
                      'goodwill na aquisicao ceramica monte carlo em 2008' : 'goodwill' , 
                      'goodwill na aquisicao da deca nordeste em 2011' : 'goodwill' , 
                      'goodwill na aquisicao da ind. metalurgica jacarei em 2012' : 'goodwill' , 
                      'goodwill na aquisicao da thermosystem em 2013' : 'goodwill' , 
                      'goodwill na aquisicao da duchacorona em 2015' : 'goodwill' , 
                      'goodwill na aquisicao da caetex florestal' : 'goodwill' , 
                      'goodwill na aquisicao da ceramica urussanga em 2017' : 'goodwill' , 
                      'goodwill na aquisicao da massima revestimentos em 2017' : 'goodwill' , 
                      'goodwill na aquisicao da cecrisa revestimentos em 2019' : 'goodwill' , 
                      'goodwill viva decora' : 'goodwill'}

replace_value_bpp = {'passivo total' : 'passivo_total' , 
                      'passivo circulante' : 'passivo_circ' , 
                      'passivos financeiros ao valor justo atraves do resultado' : 'passivo_circ' , 
                      'passivos financeiros para negociacao' : 'passivo_circ' , 
                      'emprestimos e financiamentos' : 'emprest_financ_curto' , 
                      'obrigacoes p/ titulos e valores mobiliarios' : 'emprest_financ_curto' , 
                      'outros passivos financeiros ao valor justo no resultado' : 'passivo_nao_circ' , 
                      'outros passivos financeiros designados ao valor justo atraves do resultado' : 'passivo_nao_circ' , 
                      'passivo nao circulante' : 'passivo_nao_circ' , 
                      'depositos de instituicoes de credito' : 'emprest_financ_longo' , 
                      'obrigacoes por emissao de titulos' : 'emprest_financ_longo' , 
                      'passivo exigivel a longo prazo' : 'emprest_financ_longo' , 
                      'passivos financeiros avaliados a valor justo' : 'emprest_financ_longo' , 
                      'passivos financeiros ao custo amortizado' : 'patrimonio_liquido' , 
                      'patrimonio liquido consolidado' : 'patrimonio_liquido' , 
                      'capital social realizado' : 'capital_social' , 
                      'captacao no mercado aberto' : 'reserva_capital' , 
                      'captacoes no mercado aberto' : 'reserva_capital' , 
                      'deposito a prazo e interfinanceiros' : 'reserva_capital' , 
                      'depositos a prazo e interfinanceiros' : 'reserva_capital' , 
                      'obrigacoes por emprestimos e repasses' : 'reserva_capital' , 
                      'obrigacoes por emprestimos ou de transferencia de ativosfinanceiros' : 'reserva_capital' , 
                      'passivos com clientes' : 'reserva_capital' , 
                      'recursos de emisao de titulos' : 'reserva_capital' , 
                      'recursos de emissao de titulos' : 'reserva_capital' , 
                      'reservas de capital' : 'reserva_capital' , 
                      'reservas de lucros' : 'reserva_lucros' , 
                      'lucros/prejuizos acumulados' : 'lucro_prej_acum'}

replace_value_dre = {'receita de venda de bens e ou servicos' : 'receita_liq' , 
                      'receitas da intermediacao financeira' : 'receita_liq' , 
                      'receitas das operacoes' : 'receita_liq' , 
                      'custo dos bens e ou servicos vendidos' : 'custo_prod' , 
                      'despesas da intermediacao financeira' : 'custo_prod' , 
                      'sinistros e despesas das operacoes' : 'custo_prod' , 
                      'resultado bruto' : 'lucro_bruto' , 
                      'resultado bruto intermediacao financeira' : 'lucro_bruto' , 
                      'despesas administrativas' : 'desp_operacionais' , 
                      'despesas receitas operacionais' : 'desp_operacionais' , 
                      'outras despesas receitas operacionais' : 'desp_operacionais' , 
                      'outras receitas e despesas operacionais' : 'ebit' , 
                      'resultado antes do resultado financeiro e dos tributos' : 'ebit' , 
                      'resultado financeiro' : 'result_financ' , 
                      'resultado antes dos tributos sobre o lucro' : 'ebitda' , 
                      'resultado liquido das operacoes descontinuadas' : 'ebitda' , 
                      'imposto de renda e contribuicao social sobre o lucro' : 'ir' , 
                      'resultado liquido das operacoes continuadas' : 'lucro_liq_op_contin' , 
                      'resultado liquido de operacoes descontinuadas' : 'lucro_liq_op_descontin' , 
                      'lucro prejuizo consolidado do periodo' : 'lucro_liq' , 
                      'atribuido a socios da empresa controladora' : 'lucro_liq_control' , 
                      'atribuido a socios nao controladores' : 'lucro_liq_nao_control' }

replace_value_dfc = { 'caixa liquido atividades operacionais' : 'fco' , 
                      'caixa gerado nas operacoes' : 'fco_gerado_operacao' , 
                      'lucro liquido do exercicio apos ajustes' : 'fco_gerado_operacao' , 
                      'depreciacao de bens do ativo imobilizado' : 'depreciacao' , 
                      'amortizacao de agio em investimentos' : 'amortizacao' , 
                      'amortizacao e depreciacao' : 'amortizacao_depreciacao' , 
                      'deprciacoes e amortizacoes' : 'amortizacao_depreciacao' , 
                      'deprec amortiz ativo intangivel concessao/imobilizado' : 'amortizacao_depreciacao' , 
                      'depreciacao  amortizacoes' : 'amortizacao_depreciacao' , 
                      'depreciacao /amortizacao' : 'amortizacao_depreciacao' , 
                      'depreciacao a amortizacao' : 'amortizacao_depreciacao' , 
                      'depreciacao do imobillizado e amortizacao do intangivel' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao - no resultado' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao (nota 14 e 15)' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao de ativos imobilizados e intangiveis' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao de ativos imobilizados eintangiveis' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao de bens ativo imobilizado e intangivel' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao de bens do ativo imobilizado e intangivel' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao do ativo tangivel e intangivel' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao do imobilizado e intangivel' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao do intangivel' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao*' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacoes' : 'amortizacao_depreciacao' , 
                      'depreciacao e armortizacao' : 'amortizacao_depreciacao' , 
                      'depreciacao e armotizacao' : 'amortizacao_depreciacao' , 
                      'depreciacao imobilizado' : 'amortizacao_depreciacao' , 
                      'depreciacao, amortizacao e colheita de cana-de-acucar' : 'amortizacao_depreciacao' , 
                      'depreciacao, amortizacao e impairment' : 'amortizacao_depreciacao' , 
                      'depreciacao, amortizacao e imparment' : 'amortizacao_depreciacao' , 
                      'depreciacao, amortizacaoe exaustao' : 'amortizacao_depreciacao' , 
                      'depreciacao, exaustao e amortizacao' : 'amortizacao_depreciacao' , 
                      'depreciaclao e amortizacao' : 'amortizacao_depreciacao' , 
                      'depreciacoes de imobilizado' : 'amortizacao_depreciacao' , 
                      'depreciacoes e amortizacoes' : 'amortizacao_depreciacao' , 
                      'depreciacoes e amortizacoes (nota 10,11 e 12)' : 'amortizacao_depreciacao' , 
                      'depreciacoes e amortizacoes acumuladas' : 'amortizacao_depreciacao' , 
                      'depreciacoes e amortizacoes do intangivel' : 'amortizacao_depreciacao' , 
                      'depreciacoes e armotizacoes' : 'amortizacao_depreciacao' , 
                      'depreciacoes imobilizado' : 'amortizacao_depreciacao' , 
                      'depreciacao do ativo tangivel' : 'depreciacao' , 
                      'amortizacao de intangivel - concessao' : 'amortizacao' , 
                      'amortizacao do ativo intangivel' : 'amortizacao' , 
                      'amortizacao do intangivel da concessao' : 'amortizacao' , 
                      'amortizacao do intangivel da concessao - operacoes descontinuadas' : 'amortizacao' , 
                      'amortizacao do intangivel de concessao' : 'amortizacao' , 
                      'amortizacao do intangivel de concessao - operacoes continuadas' : 'amortizacao' , 
                      'amortizacao do intangivel e diferido' : 'amortizacao' , 
                      'amortizacao dos custos de captacao de emprestimo' : 'amortizacao' , 
                      'amortizacao subsidios governamentais' : 'amortizacao' , 
                      '(ganhos) / perdas na baixa do ativo imobilzado/intangivel' : 'amortizacao_depreciacao' , 
                      'ajuste por depreciacao e amortizacao' : 'amortizacao_depreciacao' , 
                      'amoritizacao de ativos intangiveis' : 'amortizacao_depreciacao' , 
                      'depreciacao / exaustao / amortizacao' : 'depreciacao' , 
                      'depreciacao das propriedades para investimento' : 'depreciacao' , 
                      'depreciacao do custo atribuido' : 'depreciacao' , 
                      'depreciacao do imobilizado e amortizacao do intangivel' : 'depreciacao' , 
                      'depreciacao e amortizacao  - reducao de participacao em coligada' : 'depreciacao' , 
                      'depreciacao e exaustao' : 'depreciacao' , 
                      'depreciacao, amortizacao e exaustao' : 'depreciacao' , 
                      'depreciacoes' : 'depreciacao' , 
                      'depreciacoes / amortizacoes' : 'depreciacao' , 
                      'depreciacoes, amortizacoes e exaustoes' : 'depreciacao' , 
                      'depreciacoes,amortizacoes e exaustoes' : 'depreciacao' , 
                      'deprecicao e amortizacao' : 'depreciacao' , 
                      'deprecisao e armotizacao' : 'depreciacao' , 
                      'amortizacao de agio, liquida' : 'amortizacao' , 
                      'amortizacao de ativo biologico' : 'amortizacao' , 
                      'amortizacao de intangivel - outros' : 'amortizacao' , 
                      'amortizacao de mais-valia' : 'amortizacao' , 
                      'amortizacao de mais-valia, liquida' : 'amortizacao' , 
                      'amortizacao do uso do bem publico' : 'amortizacao' , 
                      'amortizacao do uso do bem publico (ubp)' : 'amortizacao' , 
                      'amortizacao dos ativos intangiveis' : 'amortizacao' , 
                      'amortizacao dos custos de captacao de emprestimos' : 'amortizacao' , 
                      'amortizacoes' : 'amortizacao' , 
                      'amortizacoes do intangivel' : 'amortizacao' , 
                      'depreciacao , amortizacao e exaustao' : 'amortizacao_depreciacao' , 
                      'depreciacao / amortizacao' : 'amortizacao_depreciacao' , 
                      'depreciacao atribuida ao estoque' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao  - reducao ao valor recuperavel' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao (investimento e intangivel)' : 'amortizacao_depreciacao' , 
                      'depreciacao e amortizacao (notas 10 e 11)' : 'amortizacao_depreciacao' , 
                      'depreciacao e apropriacao' : 'amortizacao_depreciacao' , 
                      'depreciacao e exaustao do ativo biologico' : 'amortizacao_depreciacao' , 
                      'depreciacao, deplecao e amortizacao' : 'amortizacao_depreciacao' , 
                      'depreciacoes/amortizacoes' : 'amortizacao_depreciacao' , 
                      'depreciacoes/amortizacoes/baixa de imobilizado' : 'amortizacao_depreciacao' , 
                      'amortizacao de agio de investimento' : 'amortizacao' , 
                      'amortizacao de agio na aquisicao de controlada' : 'amortizacao' , 
                      'amortizacao de agio, liquida de reversao para manutencao da integridade do patrimonio liquido' : 'amortizacao' , 
                      'amortizacao de agios' : 'amortizacao' , 
                      'amortizacao de custos de emprestimos, financiamentos, debentures e obrigacoes com parceiros' : 'amortizacao' , 
                      'amortizacao de investimentos - direito de concessao' : 'amortizacao' , 
                      'amortizacao mais valia dos estoques' : 'amortizacao' , 
                      'depreciacao' : 'depreciacao' , 
                      'depreciacao de estandes de venda' : 'depreciacao' , 
                      'depreciacao e amortizacao de bens do ativo imobilizado e intangiveis' : 'depreciacao' , 
                      'amortizacao de agio de investimentos' : 'amortizacao' , 
                      'amortizacao de ativos intangiveis' : 'amortizacao' , 
                      'amortizacao de contratos de energia' : 'amortizacao' , 
                      'amortizacao de contribuicao de parceiros' : 'amortizacao' , 
                      'amortizacao de custos de captacao' : 'amortizacao' , 
                      'amortizacao do agio, liquido de reversao para manutencao da integridade do patrimonio' : 'amortizacao' , 
                      'amortizacao do custo de captacao' : 'amortizacao' , 
                      'amortizacao do diferido' : 'amortizacao' , 
                      'depreciacao e amortizacao por aquisicao de empresa' : 'depreciacao' , 
                      'depreciacao/amortizacao' : 'depreciacao' , 
                      'depreciacoes, amortizacoes e exaustao' : 'depreciacao' , 
                      'amortizacao de agio e desagio sobre investimentos' : 'amortizacao' , 
                      'amortizacao de agio nas aquisicoes' : 'amortizacao' , 
                      'amortizacao de desagio' : 'amortizacao' , 
                      'amortizacao de despesas diferidas com emissao de titulos' : 'amortizacao' , 
                      'amortizacao do agio sobre investimentos' : 'amortizacao' , 
                      'amortizacao do direito de concessao - agio' : 'amortizacao' , 
                      'amortizacao do valor justo de contas a receber vinculadas a concessao' : 'amortizacao' , 
                      'amortizacao dos custos de emissao das debentures' : 'amortizacao' , 
                      'amortizacao e desagio' : 'amortizacao' , 
                      'amortizacao intangivel' : 'amortizacao' , 
                      'amortizacao agio propriedade para investimentos' : 'amortizacao' , 
                      'amortizacao da mais valia de aquisicoes' : 'amortizacao' , 
                      'amortizacao de agio' : 'amortizacao' , 
                      'amortizacao de ativo de concessao na aquisicao de controlada' : 'amortizacao' , 
                      'amortizacao de mais valia de ativos' : 'amortizacao' , 
                      'amortizacao de premio sobre a emissao de bonus perpetuo' : 'amortizacao' , 
                      'amortizacao intangivel e do agio' : 'amortizacao' , 
                      'amortizacao mais valia' : 'amortizacao' , 
                      'amortizacao mais valia de estoques' : 'amortizacao' , 
                      'depreciacao de ativo fixo' : 'depreciacao' , 
                      'amortizacao de custos de transacao de emprestimos' : 'amortizacao' , 
                      'amortizacao dos custos de emprestimos e debentures (nota 8)' : 'amortizacao' , 
                      'amortizacao e perdas em ativos intangiveis' : 'amortizacao' , 
                      'depreciacao e amrotizacao' : 'amortizacao_depreciacao' , 
                      'amortizacao de custo capitalizado' : 'amortizacao' , 
                      'amortizacao dos custos de captacao' : 'amortizacao' , 
                      'amortizacoes - intangivel' : 'amortizacao' , 
                      'amortizacoes de custos capitalizados' : 'amortizacao' , 
                      'depreciacao e amortizacao em ativo imobilizado' : 'amortizacao_depreciacao' , 
                      'depreciacao de ativo imobilizado' : 'depreciacao' , 
                      'amortizacao de agio e desagio na aquisicao' : 'amortizacao' , 
                      'amortizacao de despesas antecipadas' : 'amortizacao' , 
                      'amortizacao do custo de captacao, agio e desagio' : 'amortizacao' , 
                      'amortizacao emprestimos e financiamentos - encargos' : 'amortizacao' , 
                      'amortizacoes - ativo de direito de uso' : 'amortizacao' , 
                      'amortizacoes de custos de transacao de debentures' : 'amortizacao' , 
                      'amortizacao de custos de transacao sobre debentures' : 'amortizacao' , 
                      'amortizacao de encargos emprestimos e financ.' : 'amortizacao' , 
                      'amortizacao de encargos emprestimos e financiamentos' : 'amortizacao' , 
                      'amortizacao de gastos com captacao de emprestimos' : 'amortizacao' , 
                      'amortizacao de gastos com emissao de debentures' : 'amortizacao' , 
                      'amortizacao de investimento em "joint venture"' : 'amortizacao' , 
                      'amortizacao ajuste a valor presente debentures' : 'amortizacao' , 
                      'amortizacao despesas de comercializacao diferidas' : 'amortizacao' , 
                      'amortizacao do custo dos emprestimos' : 'amortizacao' , 
                      'amortizacoes de agio mais valia' : 'amortizacao' , 
                      'amortizacao agio' : 'amortizacao' , 
                      'amortizacao de entressafra' : 'amortizacao' , 
                      'amortizacao do custo de transcao' : 'amortizacao' , 
                      'amortizacao do premio de risco - gsf' : 'amortizacao' , 
                      'amortizacao de tratos cana soca' : 'amortizacao' , 
                      'amortizacao e baixa do custo de captacao' : 'amortizacao' , 
                      'amortizacao ifc e debentures' : 'amortizacao' , 
                      'amortizacao custo de transacao das debentures' : 'amortizacao' , 
                      'amortizacao de agio em investimento' : 'amortizacao' , 
                      'amortizacao de intangiveis' : 'amortizacao' , 
                      'amortizacao de remensuracao de investimento' : 'amortizacao' , 
                      'amortizacao e reversao do agio oriundo da incorporacao' : 'amortizacao' , 
                      'depreciacao direito de uso - ifrs 16' : 'depreciacao' , 
                      'amortizacao do direito de uso sobre arrendamentos eparcerias agricolas' : 'amortizacao' , 
                      'amortizacao do intangivel de concessao - operacoes descontinuadas' : 'amortizacao' , 
                      'amortizacao de custo de captacao' : 'amortizacao' , 
                      'amortizacao de custo de captacao e outros' : 'amortizacao' , 
                      'caixa liquido atividades de investimento' : 'fci' , 
                      '(aquisicao) baixa de imobilizados' : 'capex' , 
                      '(aquisicoes)/ de ativo imobilizado' : 'capex' , 
                      '(aumento) reducao de ativo imobilizado' : 'capex' , 
                      'adicao ao imobilizado, software e outros intangiveis' : 'capex' , 
                      'adicao ao imobilizado, softwares e outros intangiveis' : 'capex' , 
                      'adicao ativo imobilizado' : 'capex' , 
                      'adicao de ativo imobilizado' : 'capex' , 
                      'adicoes - imobilizado e intangivel' : 'capex' , 
                      'adicoes ao ativo imobilizado e sistemas de informatica' : 'capex' , 
                      'adicoes ativo imobilizado/intangivel' : 'capex' , 
                      'adicoes de ativo imobilizado e intangivel' : 'capex' , 
                      'adicoes de imobilizado e intagivel' : 'capex' , 
                      'adicoes de imobilizado e intangivel' : 'capex' , 
                      'adicoes de imobilizados e intangiveis' : 'capex' , 
                      'adicoes do ativo imobilizado' : 'capex' , 
                      'adicoes no ativo imobilizado' : 'capex' , 
                      'adicoes no ativo imobilizado e intangivel' : 'capex' , 
                      'adicoes no imobilizado e nos ativos biologicos' : 'capex' , 
                      'adicoes p/imobilizado' : 'capex' , 
                      'adicoes para imobilizado e intangivel' : 'capex' , 
                      'adicoes para os ativos financeiro, intangivel de concessao e imobilizado' : 'capex' , 
                      'alienacao de imobilizado' : 'capex' , 
                      'alienacao do ativo imobilizado' : 'capex' , 
                      'alienacao do ativo tangivel' : 'capex' , 
                      'alienacao no imobilizado' : 'capex' , 
                      'aplicacoes de recursos em ativos intangiveis' : 'capex' , 
                      'aplicacoes de titulos e valores mobiliarios, liquidos' : 'capex' , 
                      'aplicacoes detitulos e valores mobiliarios / aplicacao financeira vinculada' : 'capex' , 
                      'aplicacoes em ativos imobilizado e intangivel' : 'capex' , 
                      'aplicacoes em imobilizado' : 'capex' , 
                      'aquisicao ativo imobilizado e diferido' : 'capex' , 
                      'aquisicao ativo imobilizado e intangivel' : 'capex' , 
                      'aquisicao de ativo imobilizado' : 'capex' , 
                      'aquisicao de ativo imobilizado e intangivel' : 'capex' , 
                      'aquisicao de ativo imobilizado e intangivel (notas 10 e 11)' : 'capex' , 
                      'aquisicao de ativo imobilizado em servico' : 'capex' , 
                      'aquisicao de ativo imobilizado/aumento ativo imobil.(data anterior 23/04/2009)' : 'capex' , 
                      'aquisicao de bens ativo imob' : 'capex' , 
                      'aquisicao de bens ativo imobilizado' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado (liq. impostos)' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado e de itens do intangivel' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado e intangivel' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado e propriedade para investimentos' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado, liquido dos ingresos pela venda de ativos' : 'capex' , 
                      'aquisicao de bens do imob./ intangivel' : 'capex' , 
                      'aquisicao de bens do imobilizado e intangivel' : 'capex' , 
                      'aquisicao de bens para o ativo imobilizado' : 'capex' , 
                      'aquisicao de bens para o imobilizado' : 'capex' , 
                      'aquisicao de de outros imobilizado e intangiveis' : 'capex' , 
                      'aquisicao de imobilizado' : 'capex' , 
                      'aquisicao de imobilizado e intangivel' : 'capex' , 
                      'aquisicao de imobilizado, intangivel' : 'capex' , 
                      'aquisicao de imobilizado/intangivel' : 'capex' , 
                      'aquisicao de imobolizado de uso' : 'capex' , 
                      'aquisicao de outros imobilizados' : 'capex' , 
                      'aquisicao de outros imobilizados e intangivel' : 'capex' , 
                      'aquisicao do ativo imobilizado' : 'capex' , 
                      'aquisicao do imobilizado' : 'capex' , 
                      'aquisicao e baixa de imobilizado' : 'capex' , 
                      'aquisicao imobilizado e intangivel' : 'capex' , 
                      'aquisicao no ativo intangivel e imobilizado' : 'capex' , 
                      'aquisicoes ativos financeiro e intangivel de concessao' : 'capex' , 
                      'aquisicoes de ativo imobilizado' : 'capex' , 
                      'aquisicoes de ativo imobilizado e intangivel' : 'capex' , 
                      'aquisicoes de ativos imobilizado e intangivel' : 'capex' , 
                      'aquisicoes de bens do ativo imobilizado' : 'capex' , 
                      'aquisicoes de bens do ativo imobilizado e intangivel' : 'capex' , 
                      'aquisicoes de imobilizado e intangivel' : 'capex' , 
                      'aquisicoes de imobilizado e intangivel e adicoes de florestas' : 'capex' , 
                      'aquisicoes de imobilizados' : 'capex' , 
                      'aquisicoes de itens do ativo imobilizado' : 'capex' , 
                      'aquisicoes de outros imobilizados' : 'capex' , 
                      'aquisicoes do ativo imobilizado' : 'capex' , 
                      'aquisicoes do ativo imobilizado / intangivel' : 'capex' , 
                      'aquisicoes do imobilizado' : 'capex' , 
                      'aquisicoes em imobilizado e intangivel' : 'capex' , 
                      'aquisicoes no ativo intangivel' : 'capex' , 
                      'ativo imobilizado' : 'capex' , 
                      'ativos imobilizados' : 'capex' , 
                      'aumento de imobilizado' : 'capex' , 
                      'aumento no ativo imobilizado' : 'capex' , 
                      'compra de ativo imobilizado e intangivel' : 'capex' , 
                      'compra de imobilizado' : 'capex' , 
                      'compras de ativo imobilizado' : 'capex' , 
                      'compras de imobilizado' : 'capex' , 
                      'compras imobilizado, intangivel e investimento' : 'capex' , 
                      'em imobilizado e intangivel' : 'capex' , 
                      'invest. em ativos biologicos,  imobilizado e intangivel' : 'capex' , 
                      'investimento em ativo imobilizado e intangivel' : 'capex' , 
                      'investimentos - ativo tangivel' : 'capex' , 
                      'investimentos em ativo imob.e intangivel' : 'capex' , 
                      'investimentos em ativo imobilizado' : 'capex' , 
                      'investimentos em ativo permanentes' : 'capex' , 
                      'investimentos em exploracao e producao' : 'capex' , 
                      'investimentos em exploracao e producao de petroleo e gas' : 'capex' , 
                      'investimentos em sociedade por conta de participacao' : 'capex' , 
                      'investimentos no ativo tangivel' : 'capex' , 
                      'investimentos no imobilizado' : 'capex' , 
                      'investimentos no realizavel longo prazo' : 'capex' , 
                      'no ativo intangivel' : 'capex' , 
                      'no imobilizado' : 'capex' , 
                      'no realizavel de longo prazo' : 'capex' , 
                      'pagamento de compra de ativo imobilizado' : 'capex' , 
                      'pagamento de compras do imobilizado' : 'capex' , 
                      'pagamento pela compra de ativo permanente - investimentos' : 'capex' , 
                      'pagamentos - investimentos no ativo tangivel' : 'capex' , 
                      'pagamentos por compras de imobilizado' : 'capex' , 
                      'recebimento da venda de ativo imobilizado' : 'capex' , 
                      'recebimento por alienacao de ativo imobilizado' : 'capex' , 
                      'recebimento por vendas de imobilizado' : 'capex' , 
                      'recursos obtidos na venda de ativo imobilizado' : 'capex' , 
                      'recursos recebidos na venda de ativo imobilizado' : 'capex' , 
                      'recursos recebidos na venda de ativo imobilizado e intangivel' : 'capex' , 
                      'reducao no imobilizado' : 'capex' , 
                      'valor da venda de ativos imobilizados/intangiveis' : 'capex' , 
                      'valor recebido pela venda de imobilizado' : 'capex' , 
                      'venda do ativo imobilizado' : 'capex' , 
                      'vendas de ativos imobilizados' : 'capex' , 
                      'vendas de bens do ativo imobilizado e propriedade para investimentos (nota 7)' : 'capex' , 
                      'vendas de imobilizado,investimentos e intangivel' : 'capex' , 
                      '(acrescimo) do ativo imobilizado' : 'capex' , 
                      '(aquisicao) alienacao de imobilizado de uso/intangivel' : 'capex' , 
                      'acrescimo de imobilizado' : 'capex' , 
                      'acrescimo de imobilizado e intangivel' : 'capex' , 
                      'acrescimo do intangivel' : 'capex' , 
                      'acrescimo imobilizado' : 'capex' , 
                      'adicao a ativos intangiveis' : 'capex' , 
                      'adicao ativo intangivel' : 'capex' , 
                      'adicoes a intangiveis' : 'capex' , 
                      'adicoes ao ativo imobilizado' : 'capex' , 
                      'adicoes ao ativo imobilizado para investimento e intangivel' : 'capex' , 
                      'adicoes ao ativo intangivel' : 'capex' , 
                      'adicoes ao imobilizado e intangivel, liquido da captacao de emprestimos' : 'capex' , 
                      'adicoes ao imobilizado, software e outros intangiveis' : 'capex' , 
                      'adicoes ao imobilizado/intangivel' : 'capex' , 
                      'adicoes ativos intangiveis' : 'capex' , 
                      'adicoes de ativos intangiveis' : 'capex' , 
                      'adicoes de imobilizado intanfivel e diferido' : 'capex' , 
                      'adicoes de intangivel' : 'capex' , 
                      'adicoes do bens do ativo imobilizado e propriedade para investimentos (nota 7)' : 'capex' , 
                      'adicoes em contas a receber vinculadas a concessao' : 'capex' , 
                      'adicoes em imobilizado e intangiveis' : 'capex' , 
                      'adicoes em intangivel e imobilizado' : 'capex' , 
                      'adicoes no ativo intangivel' : 'capex' , 
                      'adicoes no imobilizado' : 'capex' , 
                      'adicoes no imobilizado e ativos biologicos' : 'capex' , 
                      'adicoes/baixas no imobilizado e intangivel' : 'capex' , 
                      'adicoes/baixas no imobilizado, intangivel e diferido' : 'capex' , 
                      'alienacao de ativo imobilizado' : 'capex' , 
                      'alienacao de bens do ativo imobilizado e intangivel' : 'capex' , 
                      'alienacao de bens do imobilizado/investimento' : 'capex' , 
                      'alienacao de imobilizado e intangivel' : 'capex' , 
                      'alienacao de imobilizado e intengivel' : 'capex' , 
                      'alienacao do ativo intangivel' : 'capex' , 
                      'alienacao do imobilizado' : 'capex' , 
                      'aplicacao em imobilizado' : 'capex' , 
                      'aplicacao no ativo imobilizado' : 'capex' , 
                      'aplicacao no ativo imobilizado e biologico nao corrente' : 'capex' , 
                      'aplicacoes no tangivel' : 'capex' , 
                      'aplicacoes/aquisicoes no imobilizado' : 'capex' , 
                      'aquisicao ativo imobilizado' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado  e intangivel' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado (nota 14.3)' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado (nota 14)' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado e de itens do ativo intangivel' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado e do intangivel' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado e itens do ativo intangivel' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado e propriedade para investimento' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado, propriedades para investimento e itens do ativo intangivel' : 'capex' , 
                      'aquisicao de bens do imobilizado' : 'capex' , 
                      'aquisicao de bens imob. e intang.' : 'capex' , 
                      'aquisicao de bens para imobilizado' : 'capex' , 
                      'aquisicao de imobilizado e intengivel (liquido de doacoes)' : 'capex' , 
                      'aquisicao de imobilizado, exceto veiculos' : 'capex' , 
                      'aquisicao do ativo intangivel' : 'capex' , 
                      'aquisicao do ativo tangivel' : 'capex' , 
                      'aquisicao do intangivel' : 'capex' , 
                      'aquisicao e baixa de investimento e intangivel' : 'capex' , 
                      'aquisicao/baixa de imobilizado, intangivel e diferido' : 'capex' , 
                      'aquisicoes ao imobilizado' : 'capex' , 
                      'aquisicoes de ativo intangivel' : 'capex' , 
                      'aquisicoes de bens para o ativo imobilizado' : 'capex' , 
                      'aquisicoes de imobilizado e intangivel liquido de doacoes' : 'capex' , 
                      'aquisicoes de intangivel' : 'capex' , 
                      'aquisicoes do intangivel' : 'capex' , 
                      'aquisicoes e baixas do imobilizado' : 'capex' , 
                      'aqusicao de imobilizado' : 'capex' , 
                      'aqusicao de intangivel' : 'capex' , 
                      'aqusicao de intnagivel' : 'capex' , 
                      'ativo imobilizado e intangivel' : 'capex' , 
                      'ativo no intangivel' : 'capex' , 
                      'aumento de intangiveis' : 'capex' , 
                      'aumento de intangivel' : 'capex' , 
                      'aumento do intangivel' : 'capex' , 
                      'baixa  de imobilizado' : 'capex' , 
                      'baixa de ativo imobilizado' : 'capex' , 
                      'baixa de imobilizados' : 'capex' , 
                      'baixa do intangivel' : 'capex' , 
                      'compra de ativo intangivel' : 'capex' , 
                      'compra do ativo imobilizado' : 'capex' , 
                      'compras de imobilizado e intangivel' : 'capex' , 
                      'compras de imoilizado' : 'capex' , 
                      'diferido e intangivel' : 'capex' , 
                      'diferido e intangivel e adiantamento a fornecedor' : 'capex' , 
                      'investimentos - aquisicao de ativo tangivel' : 'capex' , 
                      'investimentos - ativo intangivel' : 'capex' , 
                      'investimentos em ativo intangivel' : 'capex' , 
                      'investimentos no ativo intangivel' : 'capex' , 
                      'no ativo imobilizado' : 'capex' , 
                      'pagamento por compra de imobilizado' : 'capex' , 
                      'pagamentos - investimentos no ativo intangivel' : 'capex' , 
                      'pagamentos por compras de ativos intangiveis' : 'capex' , 
                      'pagamentos relacionados a  ativos intangiveis' : 'capex' , 
                      'proventos da venda de intangivel' : 'capex' , 
                      '(aquisicao) do intangivel' : 'capex' , 
                      '(aquisicoes)/baixas no ativo imobilizado' : 'capex' , 
                      '(aumento) reducao de imobilizado' : 'capex' , 
                      'acrescimo de intangivel' : 'capex' , 
                      'acrescimo do imobilizado' : 'capex' , 
                      'acrescimo intangivel' : 'capex' , 
                      'adicao de intangiveis' : 'capex' , 
                      'adicao de intangiveis a vista' : 'capex' , 
                      'adicoes a ativos intangiveis' : 'capex' , 
                      'adicoes ao imobilizado' : 'capex' , 
                      'adicoes ao imobilizado e intangivel' : 'capex' , 
                      'adicoes ao imobilizado, intangivel, ativos de contrato' : 'capex' , 
                      'adicoes de ativo imobilizado' : 'capex' , 
                      'adicoes de imobilizado' : 'capex' , 
                      'adicoes de outros ativos intangiveis' : 'capex' , 
                      'adicoes do ativo imobilizado, intangivel' : 'capex' , 
                      'adicoes do ativo imobilizado, intangivel e biologico' : 'capex' , 
                      'adicoes em intangiveis' : 'capex' , 
                      'agio aquisicao de investimentos - intangivel' : 'capex' , 
                      'aplicacao em intangivel' : 'capex' , 
                      'aplicacao no ativo intangivel' : 'capex' , 
                      'aplicacao no intangivel' : 'capex' , 
                      'aplicacoes no ativo intangivel' : 'capex' , 
                      'aplicacoes no ativo intangivel, liquido do caixa adquirido' : 'capex' , 
                      'aquisicao (alienacao) de imobilizado e intangiveis' : 'capex' , 
                      'aquisicao de ativo tangivel' : 'capex' , 
                      'aquisicao de ativos intangiveis' : 'capex' , 
                      'aquisicao de bens do imobilizado, liquido de alienacoes' : 'capex' , 
                      'aquisicao de bens para intangivel' : 'capex' , 
                      'aquisicao de imobilizado e adicoes ao intangivel' : 'capex' , 
                      'aquisicao de imobilizado e ativos intangiveis' : 'capex' , 
                      'aquisicao de imobilizado e intangivel aquisicao de investimento' : 'capex' , 
                      'aquisicao de imobilizados' : 'capex' , 
                      'aquisicao de imobilizados/intangiveis' : 'capex' , 
                      'aquisicao de intagiveis' : 'capex' , 
                      'aquisicao de intagivel' : 'capex' , 
                      'aquisicao de intangivel' : 'capex' , 
                      'aquisicao de terras' : 'capex' , 
                      'aquisicoes de imobilizado/intangivel' : 'capex' , 
                      'ativos intangiveis' : 'capex' , 
                      'aumento (reducao) do intangivel' : 'capex' , 
                      'aumento do ativo intangivel' : 'capex' , 
                      'aumento do ativo intangivel (nota 15.3)' : 'capex' , 
                      'aumento do ativo intangivel (nota 15)' : 'capex' , 
                      'baixa de bens de imobilizado' : 'capex' , 
                      'baixa de imobilzado e intangivel' : 'capex' , 
                      'baixa de intangivel' : 'capex' , 
                      'baixa no ativo imobilizado' : 'capex' , 
                      'baixa por venda de bens do ativo imobilizado' : 'capex' , 
                      'compra de intangiveis' : 'capex' , 
                      'compra de intangivel' : 'capex' , 
                      'compras de imobilizado e intangiveis' : 'capex' , 
                      'em imobilizado' : 'capex' , 
                      'imobilizado e ativos biologicos' : 'capex' , 
                      'intagivel' : 'capex' , 
                      'intangivel e outros' : 'capex' , 
                      'investimentos - aquisicao de ativo intangivel' : 'capex' , 
                      'investimentos no passivo nao circulante' : 'capex' , 
                      'outros de ativo imobilizado e intangpivel' : 'capex' , 
                      'pagamento na aquisicao de intangiveis' : 'capex' , 
                      'pagamento pela aquisicao de imobilizado' : 'capex' , 
                      'pagamento pela aquisicao de investimento - cme' : 'capex' , 
                      'pagamento pela compra de ativo permanente - intangivel' : 'capex' , 
                      'pagamento pela compra de imobilizado' : 'capex' , 
                      'pagementos de imobilizado' : 'capex' , 
                      'reducao de imobilizado' : 'capex' , 
                      'venda do imobilizado' : 'capex' , 
                      'venda imobilizado' : 'capex' , 
                      '(adicoes) no imobilizado e intangivel' : 'capex' , 
                      '(aquisicoes) de ativo imobilizado' : 'capex' , 
                      '(aquisicoes)/baixas no ativo intangivel' : 'capex' , 
                      'adicao ao imobilizado' : 'capex' , 
                      'adicoes ao ativo imobilizado (plantio e tratos)' : 'capex' , 
                      'adicoes ao intangivel' : 'capex' , 
                      'adicoes aos ativos imobilizados e intangiveis' : 'capex' , 
                      'adicoes aos imobilizados' : 'capex' , 
                      'alienacao de bens do ativo imobilizado' : 'capex' , 
                      'alienacao de intagiveis' : 'capex' , 
                      'alienacao de intengivel' : 'capex' , 
                      'aplicacao em custos de aquisicao diferidos (intangivel)' : 'capex' , 
                      'aplicacoes no imobilizado' : 'capex' , 
                      'aplicacoes no imobilizado e intangivel' : 'capex' , 
                      'aplicacoes no imobilizado, intangivel e ativo contratual - infra-estrutura em construcao' : 'capex' , 
                      'aplicacoes no intangivel' : 'capex' , 
                      'aplicacoes/ aquisicoes no intangivel' : 'capex' , 
                      'aquisicao ao intangivel' : 'capex' , 
                      'aquisicao de ativo intangivel' : 'capex' , 
                      'aquisicao de imobilizado de uso e intangivel' : 'capex' , 
                      'aquisicao de imobilizado de uso, intangivel e ativos biologicos' : 'capex' , 
                      'aquisicao de intagivel e agio' : 'capex' , 
                      'aquisicao de intangivel e agio' : 'capex' , 
                      'aquisicao de outros ativos imobilizados' : 'capex' , 
                      'aquisicoes / baixa de intangivel (exceto agio)' : 'capex' , 
                      'aquisicoes de ativos imobilizado' : 'capex' , 
                      'aquisicoes de ativos imobilizados e intangiveis' : 'capex' , 
                      'aquisicoes de ativos intangiveis' : 'capex' , 
                      'aquisicoes de intangivel (exceto agio)' : 'capex' , 
                      'aumento de ativo intangivel' : 'capex' , 
                      'aumento do ativo intangivel (nota 16)' : 'capex' , 
                      'baixa do ativo imobilizado' : 'capex' , 
                      'compra de ativos imobilizados e intangiveis' : 'capex' , 
                      'compras de ativos intangiveis' : 'capex' , 
                      'contas a pagar aquisicao' : 'capex' , 
                      'imobilizado - aquisicao' : 'capex' , 
                      'intangivel - outros' : 'capex' , 
                      'intangivel e diferido' : 'capex' , 
                      'no imobilizado - aquisicao' : 'capex' , 
                      'no intangivel' : 'capex' , 
                      'pagamento de imobilizado adquirido em periodos anteriores' : 'capex' , 
                      'pagamento pela aquisicao de intangivel' : 'capex' , 
                      'pagamento pela compra imobilizado' : 'capex' , 
                      '(aquisicao) de ativo imobilizado' : 'capex' , 
                      'adicao  do ativo intangivel' : 'capex' , 
                      'adicao ao intangivel' : 'capex' , 
                      'adicao de ativo intangivel' : 'capex' , 
                      'adicao de intangivel' : 'capex' , 
                      'adicao de propriedade para investimento' : 'capex' , 
                      'adicao no imobilizado e intangivel' : 'capex' , 
                      'adicao/baixas no imobilizado e intangivel' : 'capex' , 
                      'adicoes - intangivel' : 'capex' , 
                      'adicoes ao ativo biologico' : 'capex' , 
                      'adicoes ao imobilizado e intangivel, liquido da provisao (reversao) para perdas' : 'capex' , 
                      'adicoes ao imobilizado, intangivel e ativo financeiro indenizavel' : 'capex' , 
                      'adicoes do imobilizado' : 'capex' , 
                      'adicoes em imobilizado' : 'capex' , 
                      'adicoes em imobilizados' : 'capex' , 
                      'adicoes no intangivel vinculado a concessao' : 'capex' , 
                      'agio/intangivel na aquisicao de investimentos' : 'capex' , 
                      'aquisicao ativo intangivel' : 'capex' , 
                      'aquisicao de bens do ativo intangivel' : 'capex' , 
                      'aquisicao de bens do intangivel' : 'capex' , 
                      'aquisicao de bens prop.,inv.,imob. e intang.' : 'capex' , 
                      'aquisicao de imobilizado de uso, intangiveis e ativos biologicos' : 'capex' , 
                      'aquisicao de outros intangiveis' : 'capex' , 
                      'aquisicao do imobilizado e intangivel' : 'capex' , 
                      'aquisicoes de imobilizado de uso e intangivel' : 'capex' , 
                      'ativo tangivel' : 'capex' , 
                      'aumento no intangivel' : 'capex' , 
                      'compra de ativo imobilizado' : 'capex' , 
                      'compra de ativos intangiveis e imobilizado' : 'capex' , 
                      'constituicao de ativo intangivel' : 'capex' , 
                      'constituicao do ativo intangivel' : 'capex' , 
                      'intangivel - aquisicao' : 'capex' , 
                      'no intangivel - aquisicao' : 'capex' , 
                      '(aquisicoes) de bens intangiveis' : 'capex' , 
                      'adicoes de intangivel - outros' : 'capex' , 
                      'adicoes do intangivel' : 'capex' , 
                      'adicoes em outros intangiveis' : 'capex' , 
                      'adicoes no intangivel' : 'capex' , 
                      'alienacao de bens do imobilizado e intangivel' : 'capex' , 
                      'alienacao de bens do intangivel' : 'capex' , 
                      'aquisicao de bens intangiveis' : 'capex' , 
                      'aquisicoes no imobilizado' : 'capex' , 
                      'aumento de ativo imobilizado' : 'capex' , 
                      'aumento de imobilizado por compra' : 'capex' , 
                      'baixa de ativos imobilizados' : 'capex' , 
                      'baixas de ativos imobilizado' : 'capex' , 
                      'intangivel - despesas de desenvolvimento' : 'capex' , 
                      'no intangivel - despesas de desenvolvimento' : 'capex' , 
                      'pagamento na aquisicao de ativo imobilizado' : 'capex' , 
                      'venda de bens do ativo imobilizado e ppi' : 'capex' , 
                      'venda de imobilizado, liquido de desconto financeiro' : 'capex' , 
                      'vendas de imobilizados' : 'capex' , 
                      'adicao de imobilizado/ intangivel na incorporacao' : 'capex' , 
                      'adicoes ao imobilizado e intangivel e ativos da concessao' : 'capex' , 
                      'adicoes ao imobilizado, intangivel e investimento' : 'capex' , 
                      'adicoes do ativo intangivel' : 'capex' , 
                      'adicoes em intangivel' : 'capex' , 
                      'aquisicao de bens do ativo imobilizado e intangivel (nota 14 e 15)' : 'capex' , 
                      'aquisicao de bens para o ativo imobilizado e intangivel, complemento de de agio' : 'capex' , 
                      'aquisicao de imobilizado e intangiveis' : 'capex' , 
                      'aquisicao de terrenos' : 'capex' , 
                      'aquisicao intangivel por alienacao de acoes em tesouraria' : 'capex' , 
                      'aquisicoes de bens do ativo intangivel' : 'capex' , 
                      'aquisicoes de imobilizados e intangiveis' : 'capex' , 
                      'aquisicoes de imobilizadose intangiveis' : 'capex' , 
                      'ativo intangivel contas a pagar_aquisicao de empresas' : 'capex' , 
                      'ativo intangivel contas a pagar_aquisicao empresas' : 'capex' , 
                      'aumento ao intangivel' : 'capex' , 
                      'aumento de imobilizado por aquisicao de participacao' : 'capex' , 
                      'baixa do imobilizado por ajuste de inventario' : 'capex' , 
                      'baixas no imobilizado' : 'capex' , 
                      'pagamento pela compra de ativo imobilizado' : 'capex' , 
                      'adicoes (reducoes) ao intangivel' : 'capex' , 
                      'alienacao/baixa de ativo imobilizado' : 'capex' , 
                      'aquisicao de ativos intangiveis - sistema erp' : 'capex' , 
                      'aquisicao de intangiveis' : 'capex' , 
                      'aquisicoes de bens intangiveis' : 'capex' , 
                      'aquisicoes de imobilizado de uso' : 'capex' , 
                      'aquisicoes de intangiveis' : 'capex' , 
                      'baixa de ativo intangivel' : 'capex' , 
                      'baixa de ativos intangiveis' : 'capex' , 
                      'intangivies' : 'capex' , 
                      'alienacao - ativo intangivel' : 'capex' , 
                      'aquisicao de ativos tangiveis' : 'capex' , 
                      'aquisicao no intangivel' : 'capex' , 
                      'aquisicao de imobilizado de uso' : 'capex' , 
                      'aquisicoes de imobilizado' : 'capex' , 
                      'caixa liquido atividades de financiamento' : 'fcf' , 
                      'aquisicao acoes em tesouraria' : 'acoes_tesouraria' , 
                      'aquisicao de acoes de emissao propria' : 'acoes_tesouraria' , 
                      'dividendos / jscp pagos no exercicio' : 'dividendos_jcp' , 
                      'dividendos / juros acionistas' : 'dividendos_jcp' , 
                      'dividendos / juros acionistas - lei 9249/95' : 'dividendos_jcp' , 
                      'dividendos e jcp a acionistas' : 'dividendos_jcp' , 
                      'dividendos e juros capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos e juros de capital proprio prescritos' : 'dividendos_jcp' , 
                      'dividendos e juros s/ capital proprio' : 'dividendos_jcp' , 
                      'dividendos e juros sobre capital prorpio' : 'dividendos_jcp' , 
                      'dividendos e juros sobre o capital proprio prescritos' : 'dividendos_jcp' , 
                      'dividendos e juros sobre o capital proprios prescritos' : 'dividendos_jcp' , 
                      'dividendos jscp pagos' : 'dividendos_jcp' , 
                      'dividendos/ jcp pagos' : 'dividendos_jcp' , 
                      'juros s/ capital proprio pagos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio' : 'dividendos_jcp' , 
                      'juros sobre capital proprio ou dividendos pagos' : 'dividendos_jcp' , 
                      'juros sobre o capital prooprio' : 'dividendos_jcp' , 
                      'juros sobre o capital proprio e dividendos pagos' : 'dividendos_jcp' , 
                      'juros sobre o capital proprio ou dividendos pagos' : 'dividendos_jcp' , 
                      'juros sobre o capital proprio pagos e dividendos pagos' : 'dividendos_jcp' , 
                      'lucros distribuidos' : 'dividendos_jcp' , 
                      'pagamento de dividendos e juros s/capital proprio' : 'dividendos_jcp' , 
                      'pagamento de dividendos e juros sobre o capital proprio' : 'dividendos_jcp' , 
                      'pagamento de dividendos/lucros aos acionistas' : 'dividendos_jcp' , 
                      'pagamento de juros s/capital proprio dividendos' : 'dividendos_jcp' , 
                      'pagamentos - dividendos' : 'dividendos_jcp' , 
                      'pagamentos de dividendos' : 'dividendos_jcp' , 
                      'pagamentos de dividendos e juros s/ cap.proprio' : 'dividendos_jcp' , 
                      'pagamentos juros s/ capital proprio e dividendos' : 'dividendos_jcp' , 
                      'pagto de dividendos e juros de capital proprio' : 'dividendos_jcp' , 
                      'pagto dividendos e juros s/capital proprio' : 'dividendos_jcp' , 
                      'accoes em tesouraria' : 'acoes_tesouraria' , 
                      'aquisicao de acoes para tesouraria' : 'acoes_tesouraria' , 
                      'aquisicao de acoes proprias - em tesouraria' : 'acoes_tesouraria' , 
                      'recompra de acoes - em tesouraria' : 'acoes_tesouraria' , 
                      'recompra de acoes de acionistas nao controladores' : 'acoes_tesouraria' , 
                      'dividendos distribuidos' : 'dividendos_jcp' , 
                      'dividendos e jscp pagos' : 'dividendos_jcp' , 
                      'dividendos e juros sobre o capital proprio' : 'dividendos_jcp' , 
                      'dividendos e juros sobre o capital proprio distribuidos' : 'dividendos_jcp' , 
                      'dividendos e juros sobre o capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos intermediarios pagos' : 'dividendos_jcp' , 
                      'dividendos juros sobre o capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos minimos obrigatorios' : 'dividendos_jcp' , 
                      'dividendos pagos a acionistas do grupo' : 'dividendos_jcp' , 
                      'dividendos pagos aos acionistas' : 'dividendos_jcp' , 
                      'dividendos pagos e juros sobre o capital proprio' : 'dividendos_jcp' , 
                      'dividendos/jcp pagos' : 'dividendos_jcp' , 
                      'dividendos/lucros distribuidos' : 'dividendos_jcp' , 
                      'juros de capital proprio e dividendos pagos' : 'dividendos_jcp' , 
                      'juros s/capital proprio' : 'dividendos_jcp' , 
                      'juros sobre capital proprio/dividendos' : 'dividendos_jcp' , 
                      'juros sobre o capital proprio pagos' : 'dividendos_jcp' , 
                      'pagamento de dividendos' : 'dividendos_jcp' , 
                      'pagamento de dividendos a acionistas' : 'dividendos_jcp' , 
                      'pagamento de dividendos a acionistas(correcao)' : 'dividendos_jcp' , 
                      'pagamento dividendos e juros s/ capital proprio' : 'dividendos_jcp' , 
                      'remuneracao paga a acionistas' : 'dividendos_jcp' , 
                      'remuneracao paga aos acionistas' : 'dividendos_jcp' , 
                      '(aquisicao) alienacao de acoes de emissao propria' : 'acoes_tesouraria' , 
                      '(aquisicao)/alienacao de acoes em tesouraria' : 'acoes_tesouraria' , 
                      'aquisicao de acoes controladas' : 'acoes_tesouraria' , 
                      'aquisicao de acoes controladas e recompra acoes' : 'acoes_tesouraria' , 
                      'aquisicao de acoes controladas e recompra de acoes' : 'acoes_tesouraria' , 
                      'aquisicao de acoes de controladas' : 'acoes_tesouraria' , 
                      'aquisicao de acoes de controladas e recompra e venda de acoes' : 'acoes_tesouraria' , 
                      'aquisicao de acoes para manutencao de tesouraria' : 'acoes_tesouraria' , 
                      'aquisicoes de acoes proprias' : 'acoes_tesouraria' , 
                      'dividendo e juros sobre o capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos / juros s/ capital pagos' : 'dividendos_jcp' , 
                      'dividendos complementares' : 'dividendos_jcp' , 
                      'dividendos declarados e nao pagos' : 'dividendos_jcp' , 
                      'dividendos e jcp pagos' : 'dividendos_jcp' , 
                      'dividendos e juros sobre capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos e juros sobre capital proprios pagos - acionistas controladores' : 'dividendos_jcp' , 
                      'dividendos e reservas' : 'dividendos_jcp' , 
                      'dividendos pagos aos acionistas da companhia' : 'dividendos_jcp' , 
                      'dividendos/jscp pagos' : 'dividendos_jcp' , 
                      'juros sobre capital e dividendos pagos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio e dividendos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio pagos' : 'dividendos_jcp' , 
                      'pagamento de dividendos a acionistas nao controladores' : 'dividendos_jcp' , 
                      'pagamento de dividendos e juros do capital proprio' : 'dividendos_jcp' , 
                      'pagamento de dividendos e juros s/ capital proprio' : 'dividendos_jcp' , 
                      'pagamento de dividendos e juros sobre capital proprio' : 'dividendos_jcp' , 
                      'pagamento de dividendos e/ou jcp' : 'dividendos_jcp' , 
                      'pagamento de juros s/capital proprio' : 'dividendos_jcp' , 
                      'pagamento de juros sobre o capital proprio e dividendos' : 'dividendos_jcp' , 
                      'pagamentos de dividendos e juros s/ capital proprio' : 'dividendos_jcp' , 
                      'aquisicao de acoes de controladas e recompra de acoes' : 'acoes_tesouraria' , 
                      'aquisicao de acoes para manutencao em tesouraria' : 'acoes_tesouraria' , 
                      'compra de acoes para manutencao em tesouraria' : 'acoes_tesouraria' , 
                      'compra de acoes proprias' : 'acoes_tesouraria' , 
                      'distribuicao de lucro' : 'dividendos_jcp' , 
                      'dividendo e juros sobre capital proprios pagos' : 'dividendos_jcp' , 
                      'dividendos distribuidos e jcp pagos' : 'dividendos_jcp' , 
                      'dividendos e jscp pagos a acionistas nao controladores da smiles' : 'dividendos_jcp' , 
                      'dividendos e juros s/ capital proprio pago' : 'dividendos_jcp' , 
                      'dividendos e juros sobre capital proprio' : 'dividendos_jcp' , 
                      'dividendos e juros sobre capital proprio pagos aos acionistas da companhia' : 'dividendos_jcp' , 
                      'dividendos e juros sobre capital proprios' : 'dividendos_jcp' , 
                      'dividendos e outros' : 'dividendos_jcp' , 
                      'dividendos ou juros sobre capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos pagos' : 'dividendos_jcp' , 
                      'dividendos pagos a acionistas' : 'dividendos_jcp' , 
                      'dividendos pagos pela controladora' : 'dividendos_jcp' , 
                      'dividendos,juros sobre capital proprio e participacoes' : 'dividendos_jcp' , 
                      'dividendos/jcp pagos a acionistas' : 'dividendos_jcp' , 
                      'dividendos/juros sobre capital proprio - pagamento' : 'dividendos_jcp' , 
                      'juros sobre o capital proprio pago' : 'dividendos_jcp' , 
                      'pagamento de dividendos e juros sobre o capital ("jcp")' : 'dividendos_jcp' , 
                      'pagamento de dividentos/juros do capital proprio' : 'dividendos_jcp' , 
                      'pagamento de juros s/ capital proprio' : 'dividendos_jcp' , 
                      'pagamento de juros sobre capital proprio e dividendos' : 'dividendos_jcp' , 
                      'pagamento e juros s/capital proprio' : 'dividendos_jcp' , 
                      'pagamentos de dividendos e juros sobre o capital proprio' : 'dividendos_jcp' , 
                      'pagamentos de juros capital proprio-dividendos' : 'dividendos_jcp' , 
                      'proventos (aquisicao) de acoes proprias' : 'dividendos_jcp' , 
                      'proventos de emprestimos' : 'dividendos_jcp' , 
                      'proventos/(recompra) de acoes' : 'dividendos_jcp' , 
                      'acoes em tesouraria e outras' : 'acoes_tesouraria' , 
                      'acoes em tesouraria, liquido das acoes exercidas' : 'acoes_tesouraria' , 
                      'aquisicao de acoes de nao controladores' : 'acoes_tesouraria' , 
                      'aquisicao de acoes em tesouraria, liquida de recebimento pelas opcoes de acoes exercidas' : 'acoes_tesouraria' , 
                      'aquisicao de acoes para manutencao em tesouraria para atendimento de exercicio de opcoes' : 'acoes_tesouraria' , 
                      'aquisicao de acoes proprias' : 'acoes_tesouraria' , 
                      'compra das acoes em tesouraria' : 'acoes_tesouraria' , 
                      'compra de acoes proprias para manutencao em tesouraria' : 'acoes_tesouraria' , 
                      'recompra de acoes - direito de retirada' : 'acoes_tesouraria' , 
                      'recompra de acoes em tesouraria' : 'acoes_tesouraria' , 
                      'recompra de acoes p/ manutencao em tesouraria' : 'acoes_tesouraria' , 
                      'recompra de acoes preferenciais (nota 23)' : 'acoes_tesouraria' , 
                      'recompra p/manutencao em tesouraria' : 'acoes_tesouraria' , 
                      'dividendos / juros sobre o capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos complementar, pagos ao exercicio anterior' : 'dividendos_jcp' , 
                      'dividendos declarados / distribuicao lucros acumulados' : 'dividendos_jcp' , 
                      'dividendos destinados e nao pagos a minoritarios' : 'dividendos_jcp' , 
                      'dividendos e jco distribuidos e pagos' : 'dividendos_jcp' , 
                      'dividendos e jcp  pagos a acionistas' : 'dividendos_jcp' , 
                      'dividendos e juros pagos' : 'dividendos_jcp' , 
                      'dividendos e juros s/ cap. proprio pagos' : 'dividendos_jcp' , 
                      'dividendos e juros s/ o capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos e juros s/capital prop. pagos' : 'dividendos_jcp' , 
                      'dividendos e juros sobre capital proprios pagos' : 'dividendos_jcp' , 
                      'dividendos e/ou juros s/ cap. proprio pagos' : 'dividendos_jcp' , 
                      'dividendos pagos e juros sobre capital o proprio' : 'dividendos_jcp' , 
                      'dividendos ressarcidos pelos administradores' : 'dividendos_jcp' , 
                      'dividendos/jcp destinados e nao pagos' : 'dividendos_jcp' , 
                      'jcp e dividendos pagos aos acionistas' : 'dividendos_jcp' , 
                      'juros brutos sobre o capital proprio pagos' : 'dividendos_jcp' , 
                      'juros s/cap. proprio pagos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio a pagar' : 'dividendos_jcp' , 
                      'juros sobre capital proprio e dividendos pagos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio pagos, liquido de impostos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio/dividendos pagos' : 'dividendos_jcp' , 
                      'juros sobre o capital proprio e dividendos' : 'dividendos_jcp' , 
                      'juros sobre o capital proprio/dividendos pagos' : 'dividendos_jcp' , 
                      'pagamento de dividendos aos nao-controladores' : 'dividendos_jcp' , 
                      'pagamento de dividendos propostos e adicionais' : 'dividendos_jcp' , 
                      'pagamento de dividendos/pagamento restituicao de capital a acionistas' : 'dividendos_jcp' , 
                      'pagamento dos juros s/capital proprio e dividendos' : 'dividendos_jcp' , 
                      'proventos / recompra de acoes em tesouraria' : 'dividendos_jcp' , 
                      'proventos de acoes proprias' : 'dividendos_jcp' , 
                      '(compra) venda de acoes da propria companhia (mantidas em tesouraria)' : 'acoes_tesouraria' , 
                      'acoes e tesouraria' : 'acoes_tesouraria' , 
                      'acoes em tesouraria, adquiridas' : 'acoes_tesouraria' , 
                      'acoes em tesouraria, liquidas' : 'acoes_tesouraria' , 
                      'aquisicao / alienacao de acoes em tesouraria' : 'acoes_tesouraria' , 
                      'aquisicao de acoes de acionistas nao controladores' : 'acoes_tesouraria' , 
                      'aquisicao de acoes em tesouraria' : 'acoes_tesouraria' , 
                      'aquisicao de acoes para permanencia em tesouraria' : 'acoes_tesouraria' , 
                      'aquisicao de acoes para tesouraria, liquido' : 'acoes_tesouraria' , 
                      'compra de acoes' : 'acoes_tesouraria' , 
                      'recompra de acoes da companhia' : 'acoes_tesouraria' , 
                      'recompra de acoes proprias' : 'acoes_tesouraria' , 
                      'distribuicao de dividendos' : 'dividendos_jcp' , 
                      'distribuicao de jcp' : 'dividendos_jcp' , 
                      'dividendos a pagar' : 'dividendos_jcp' , 
                      'dividendos declarados / distribuicao de lucros acumulados' : 'dividendos_jcp' , 
                      'dividendos e jcp  pagos s/ acoes resgataveis' : 'dividendos_jcp' , 
                      'dividendos e juros s/o capital proprio pagos' : 'dividendos_jcp' , 
                      'dividendos fixos  pagos s/ acoes resgataveis' : 'dividendos_jcp' , 
                      'dividendos pagos a acionistas nao controladores' : 'dividendos_jcp' , 
                      'dividendos pagos no exercicio' : 'dividendos_jcp' , 
                      'dividendos pagos para acionistas nao controladores' : 'dividendos_jcp' , 
                      'juros s/capital proprio e dividendos pagos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio e dividendos a pagar' : 'dividendos_jcp' , 
                      'juros sobre capital proprio pago' : 'dividendos_jcp' , 
                      'juros sobre capital proprio/dividendos a pagar' : 'dividendos_jcp' , 
                      'pagamento de dividendos aos acionistas' : 'dividendos_jcp' , 
                      'pagamento de dividendos e jcp' : 'dividendos_jcp' , 
                      'pagamento de dividendos e juros sobre capitla proprio' : 'dividendos_jcp' , 
                      'pagamento de dividendos nao controladores' : 'dividendos_jcp' , 
                      'pagamento de jscp e dividendos' : 'dividendos_jcp' , 
                      'pagamentos de dividendos e jcp' : 'dividendos_jcp' , 
                      'pagto dividendos e juros capital proprio' : 'dividendos_jcp' , 
                      'pagto.dividendos e juros capital proprio' : 'dividendos_jcp' , 
                      'pgto de dividendos e jscp' : 'dividendos_jcp' , 
                      'proventos (aquisicoes) de acoes proprias' : 'dividendos_jcp' , 
                      'acoes em tesouraria alienadas' : 'acoes_tesouraria' , 
                      'aquisicao acoes para tesouraria' : 'acoes_tesouraria' , 
                      'aquisicao adicional de acoes da emeis' : 'acoes_tesouraria' , 
                      'aquisicoes de acoes em tesouraria' : 'acoes_tesouraria' , 
                      'pagamento pela recompra de acoes' : 'acoes_tesouraria' , 
                      'recompra de acoes (em tesouraria)' : 'acoes_tesouraria' , 
                      'dividendos distribuidos por controlada' : 'dividendos_jcp' , 
                      'dividendos e participacoes pagos' : 'dividendos_jcp' , 
                      'dividendos e/ou juros sobre capital proprio' : 'dividendos_jcp' , 
                      'dividendos pagos aos acionistas controladores' : 'dividendos_jcp' , 
                      'dividendos pagos por controladas a acionistas nao controladores' : 'dividendos_jcp' , 
                      'jcp e dividendos pagos e acionistas' : 'dividendos_jcp' , 
                      'pagamento de juros sobre capital proprio' : 'dividendos_jcp' , 
                      'pagamentos de dividendos e juros s/capital proprio' : 'dividendos_jcp' , 
                      'aqui. de acoes p/ manuten. em tesouraria' : 'acoes_tesouraria' , 
                      'aquisicoes de acoes de emissao propria' : 'acoes_tesouraria' , 
                      'recompa de acoes' : 'acoes_tesouraria' , 
                      'recompra de acoes - programa de compra de acoes' : 'acoes_tesouraria' , 
                      'recompra de acoes de propria emissao' : 'acoes_tesouraria' , 
                      'recompra de acoes no mercado' : 'acoes_tesouraria' , 
                      'distribuicao de juros sobre capital proprio' : 'dividendos_jcp' , 
                      'dividendos e jscp pagos aos acionistas da neoenergia' : 'dividendos_jcp' , 
                      'dividendos e juros sobre o capital proprio pagos a acionistas nao controladores' : 'dividendos_jcp' , 
                      'dividendos pagos a minoritarios' : 'dividendos_jcp' , 
                      'dividendos pagos aos acionistas nao controladores' : 'dividendos_jcp' , 
                      'juros de capital proprio pagos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio pagos, liquidos de impostos' : 'dividendos_jcp' , 
                      'pagamento de jscp' : 'dividendos_jcp' , 
                      'aquisicoes de acoes para tesouraria' : 'acoes_tesouraria' , 
                      'recompra de acoes preferenciais resgataveis' : 'acoes_tesouraria' , 
                      'distribuicao de lucros' : 'dividendos_jcp' , 
                      'dividendos e jscp pagos aos acionistas nao controladores' : 'dividendos_jcp' , 
                      'dividendos pago' : 'dividendos_jcp' , 
                      'dividendos pagos a acionistas controladores' : 'dividendos_jcp' , 
                      'dividendos pagos a acionistas da controladora' : 'dividendos_jcp' , 
                      'pagamento de juros sobre o capital proprio' : 'dividendos_jcp' , 
                      'acoes em tesouraria vendidas' : 'acoes_tesouraria' , 
                      'acoes pagas para acionistas preferenciais' : 'acoes_tesouraria' , 
                      'aquisicao de novas acoes da controlada vicar' : 'acoes_tesouraria' , 
                      'pagamento de acoes em tesouraria' : 'acoes_tesouraria' , 
                      'recompra de acoes preferenciais' : 'acoes_tesouraria' , 
                      'dividendos a pagar / (pagos) a acionistas nao controladores' : 'dividendos_jcp' , 
                      'dividendos pagos a nao controladores' : 'dividendos_jcp' , 
                      'pagamento de dividentos scps' : 'dividendos_jcp' , 
                      'aquisicao de acoes em tesouraria ppc' : 'acoes_tesouraria' , 
                      'dividendos pagos aos acionistas nao controladores - multiplus e mercosur' : 'dividendos_jcp' , 
                      'dividendos pagos e juros sobre capital proprio' : 'dividendos_jcp' , 
                      'juros sobre capital proprio pagos a nao controladores e dividendos pagos' : 'dividendos_jcp' , 
                      'pagamento de dividendos - acionista nao controlador' : 'dividendos_jcp' , 
                      'jscp e dividendos pagos' : 'dividendos_jcp' , 
                      'dividendos (pagos)' : 'dividendos_jcp' , 
                      'dividendos pagos aos nao controladores' : 'dividendos_jcp' , 
                      'dividendos (controladas) pagos a minoritarios' : 'dividendos_jcp' , 
                      'dividendos minimos e adicionais pagos' : 'dividendos_jcp' , 
                      'juros sobre capital proprio pagos a acionistas nao controladores da smiles' : 'dividendos_jcp' , 
                      'dividendos pagos a acionistas preferencialistas' : 'dividendos_jcp' ,
                      'saldo final de caixa e equivalentes' : 'saldo_final_caixa' }

# %% [markdown]
# # **DRE Escolhida Replace**

# %%
replace_value_bpa = {'ativo total' : 'ativo_total' ,
                      'ativo circulante' : 'ativo_circ' , 
                      'caixa e depositos bancarios' : 'caixa_equival' , 
                      'caixa e disponibilidade em bancos' : 'caixa_equival' , 
                      'caixa e disponibilidades em bancos' : 'caixa_equival' , 
                      'caixa e equivalentes de caixa' : 'caixa_equival' , 
                      'disponibilidades' : 'caixa_equival' , 
                      'disponibilidades e reservas no banco central do brasil' : 'caixa_equival' , 
                      'disponibilidades e saldos com o banco central' : 'caixa_equival' , 
                      'disponibilidades e saldos com o banco central do brasil' : 'caixa_equival' , 
                      'disponivel e saldos no banco central da republica argentina' : 'caixa_equival' ,
                      'aplicacoes financeiras' : 'aplicacoes_financ' , 
                      'aplicacoes no mercado aberto (antes da adocao do ifrs 9)' : 'aplicacoes_financ' , 
                      'contas especiais de garantia em bancos centrais' : 'aplicacoes_financ' , 
                      'depositos compulsorios no banco central' : 'aplicacoes_financ' , 
                      'depositos interfinanceiros' : 'aplicacoes_financ' , 
                      'emprestimos a instituicoes financeiras' : 'aplicacoes_financ' , 
                      'relacoes interfinanceiras' : 'aplicacoes_financ' , 
                      'reservas no banco central' : 'aplicacoes_financ' , 
                      'reservas no banco central e aplicacao no mercado aberto' : 'aplicacoes_financ' , 
                      'saldos em outras entidades financeiras' : 'aplicacoes_financ',
                      'ativo nao circulante' : 'ativo_nao_circ' , 
                      'ativos financeiros' : 'ativo_nao_circ' }

replace_value_bpp = {'passivo total' : 'passivo_total' , 
                      'passivo circulante' : 'passivo_circ' , 
                      'passivos financeiros ao valor justo atraves do resultado' : 'passivo_circ' , 
                      'passivos financeiros para negociacao' : 'passivo_circ' ,
                      'outros passivos financeiros ao valor justo no resultado' : 'passivo_nao_circ' , 
                      'outros passivos financeiros designados ao valor justo atraves do resultado' : 'passivo_nao_circ' , 
                      'passivo nao circulante' : 'passivo_nao_circ' , 
                      'passivos financeiros ao custo amortizado' : 'patrimonio_liquido' , 
                      'patrimonio liquido consolidado' : 'patrimonio_liquido'}

replace_value_dre = { 'receita de venda de bens e ou servicos' : 'receita_liq' , 
                      'receitas da intermediacao financeira' : 'receita_liq' , 
                      'receitas das operacoes' : 'receita_liq' , 
                      'outras receitas e despesas operacionais' : 'ebit' , 
                      'resultado antes do resultado financeiro e dos tributos' : 'ebit' ,
                      'lucro prejuizo consolidado do periodo' : 'lucro_liq'}

replace_value_dfc = { 'caixa liquido atividades operacionais' : 'fco' }

# %% [markdown]
# # **3 Convert CSV**

# %%
# import BPA
bpa_01_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2010.csv')
bpa_02_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2011.csv')
bpa_03_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2012.csv')
bpa_04_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2013.csv')
bpa_05_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2014.csv')
bpa_06_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2015.csv')
bpa_07_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2016.csv')
bpa_08_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2017.csv')
bpa_09_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2018.csv')
bpa_10_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2019.csv')
bpa_11_csv = ('/content/drive/MyDrive/Bovespa/BPA/dfp_cia_aberta_BPA_con_2020.csv')

# edicao e juncao do BPA
bpa_01 = pd.read_csv(bpa_01_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_02 = pd.read_csv(bpa_02_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_03 = pd.read_csv(bpa_03_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_04 = pd.read_csv(bpa_04_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_05 = pd.read_csv(bpa_05_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_06 = pd.read_csv(bpa_06_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_07 = pd.read_csv(bpa_07_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_08 = pd.read_csv(bpa_08_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_09 = pd.read_csv(bpa_09_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_10 = pd.read_csv(bpa_10_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpa_11 = pd.read_csv(bpa_11_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')

bpa = pd.concat([bpa_01 , bpa_02 , bpa_03 , bpa_04 , bpa_05 , bpa_06 , bpa_07 , bpa_08 , bpa_09 , bpa_10 , bpa_11 ], ignore_index=True)
bpa['VL_CONTA'] = bpa['VL_CONTA'].astype(str)
bpa['VL_CONTA'] = bpa['VL_CONTA'].str.replace('.0000000000', ' ')
bpa['VL_CONTA'] = bpa['VL_CONTA'].astype(int)
bpa['DT_REFER'] = pd.to_datetime(bpa['DT_REFER'])
bpa['CD_CVM'] = bpa['CD_CVM'].astype(int)
bpa['DT_FIM_EXERC'] = pd.to_datetime(bpa['DT_FIM_EXERC'])

# Limpando as colunas do df
bpa = bpa.drop(['DT_REFER' ,
                'VERSAO' , 
                'GRUPO_DFP' , 
                'MOEDA' ,
                'ESCALA_MOEDA' , 
                'ORDEM_EXERC' , 
                'ST_CONTA_FIXA'] , axis=1)

# Modificando posicao das colunas
bpa = bpa[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'DT_FIM_EXERC' , 'CD_CONTA' , 'DS_CONTA' , 'VL_CONTA']]
bpa = bpa.sort_values(by=['DENOM_CIA' , 'CD_CONTA' ], ascending=True)

# Diminuia para minuscula
bpa['DS_CONTA'] = bpa['DS_CONTA'].str.lower()

# codigo limpa todos os pontos
bpa['DS_CONTA'] = bpa['DS_CONTA'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# Substitui CD_CONTA para padrao
bpa = (bpa.replace({'DS_CONTA' : replace_value_bpa} , regex=True).astype(str))

# Dropa as duplicadas
bpa.drop_duplicates(subset=None, keep="first", inplace=True)

# bpa.count

# %%
# import BPP
bpp_01_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2010.csv')
bpp_02_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2011.csv')
bpp_03_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2012.csv')
bpp_04_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2013.csv')
bpp_05_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2014.csv')
bpp_06_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2015.csv')
bpp_07_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2016.csv')
bpp_08_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2017.csv')
bpp_09_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2018.csv')
bpp_10_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2019.csv')
bpp_11_csv = ('/content/drive/MyDrive/Bovespa/BPP/dfp_cia_aberta_BPP_con_2020.csv')

# edicao e juncao do BPA
bpp_01 = pd.read_csv(bpp_01_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_02 = pd.read_csv(bpp_02_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_03 = pd.read_csv(bpp_03_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_04 = pd.read_csv(bpp_04_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_05 = pd.read_csv(bpp_05_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_06 = pd.read_csv(bpp_06_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_07 = pd.read_csv(bpp_07_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_08 = pd.read_csv(bpp_08_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_09 = pd.read_csv(bpp_09_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_10 = pd.read_csv(bpp_10_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
bpp_11 = pd.read_csv(bpp_11_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')

bpp = pd.concat([bpp_01 , bpp_02 , bpp_03 , bpp_04 , bpp_05 , bpp_06 , bpp_07 , bpp_08 , bpp_09 , bpp_10 , bpp_11 ], ignore_index=True)
bpp['VL_CONTA'] = bpp['VL_CONTA'].astype(str)
bpp['VL_CONTA'] = bpp['VL_CONTA'].str.replace('.0000000000', ' ')
bpp['VL_CONTA'] = bpp['VL_CONTA'].astype(int)
bpp['DT_REFER'] = pd.to_datetime(bpp['DT_REFER'])
bpp['CD_CVM'] = bpp['CD_CVM'].astype(int)
bpp['DT_FIM_EXERC'] = pd.to_datetime(bpp['DT_FIM_EXERC'])

# Limpando as colunas do df
bpp = bpp.drop(['DT_REFER' ,
                'VERSAO' , 
                'GRUPO_DFP' , 
                'MOEDA' ,
                'ESCALA_MOEDA' , 
                'ORDEM_EXERC' , 
                'ST_CONTA_FIXA'] , axis=1)

# Modificando posicao das colunas
bpp = bpp[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'DT_FIM_EXERC' , 'CD_CONTA' , 'DS_CONTA' , 'VL_CONTA']]
bpp = bpp.sort_values(by=['DENOM_CIA' , 'CD_CONTA' ], ascending=True)

# Diminuia para minuscula
bpp['DS_CONTA'] = bpp['DS_CONTA'].str.lower()

# codigo limpa todos os pontos
bpp['DS_CONTA'] = bpp['DS_CONTA'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# Substitui CD_CONTA para padrao
bpp = (bpp.replace({'DS_CONTA' : replace_value_bpp} , regex=True).astype(str))

# Dropa as duplicadas
bpp.drop_duplicates(subset=None, keep="first", inplace=True)

# bpp.count

# %%
# import DRE
dre_01_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2010.csv')
dre_02_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2011.csv')
dre_03_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2012.csv')
dre_04_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2013.csv')
dre_05_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2014.csv')
dre_06_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2015.csv')
dre_07_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2016.csv')
dre_08_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2017.csv')
dre_09_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2018.csv')
dre_10_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2019.csv')
dre_11_csv = ('/content/drive/MyDrive/Bovespa/DRE/dfp_cia_aberta_DRE_con_2020.csv')

# edicao e juncao do DRE
dre_01 = pd.read_csv(dre_01_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_02 = pd.read_csv(dre_02_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_03 = pd.read_csv(dre_03_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_04 = pd.read_csv(dre_04_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_05 = pd.read_csv(dre_05_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_06 = pd.read_csv(dre_06_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_07 = pd.read_csv(dre_07_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_08 = pd.read_csv(dre_08_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_09 = pd.read_csv(dre_09_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_10 = pd.read_csv(dre_10_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dre_11 = pd.read_csv(dre_11_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')

dre = pd.concat([dre_01 , dre_02 , dre_03 , dre_04 , dre_05 , dre_06 , dre_07 , dre_08 , dre_09 , dre_10 , dre_11], ignore_index=True)
dre['VL_CONTA'] = dre['VL_CONTA'].astype(str)
dre['VL_CONTA'] = dre['VL_CONTA'].str.replace('.0000000000', ' ')
dre.VL_CONTA = dre.VL_CONTA.str.split('.').str[0].astype(int)
dre['DT_REFER'] = pd.to_datetime(dre['DT_REFER'])
dre['CD_CVM'] = dre['CD_CVM'].astype(int)
dre['DT_FIM_EXERC'] = pd.to_datetime(dre['DT_FIM_EXERC'])

# Limpando as colunas do df
dre = dre.drop(['DT_REFER' ,
                'VERSAO' , 
                'GRUPO_DFP' , 
                'MOEDA' ,
                'ESCALA_MOEDA' , 
                'ORDEM_EXERC' , 
                'ST_CONTA_FIXA'] , axis=1)

# Modificando posicao das colunas
dre = dre[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'DT_FIM_EXERC' , 'CD_CONTA' , 'DS_CONTA' , 'VL_CONTA']]
dre = dre.sort_values(by=['DENOM_CIA' , 'CD_CONTA' ], ascending=True)

# codigo retira todos os acentos
dre['DS_CONTA'] = dre['DS_CONTA'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# codigo deixa todos em minuscula lower = minuscula upper = maiuscula
dre['DS_CONTA'] = dre['DS_CONTA'].str.lower()

# codigo para substituir string em uma coluna
dre['DS_CONTA'] = dre.DS_CONTA.str.replace('-', ' ').str.replace('/', ' ').str.replace('.', ' ')

# Diminuia para minuscula
dre['DS_CONTA'] = dre['DS_CONTA'].str.lower()

# codigo limpa todos os pontos
dre['DS_CONTA'] = dre['DS_CONTA'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# Substitui CD_CONTA para padrao
dre = (dre.replace({'DS_CONTA' : replace_value_dre} , regex=True).astype(str))

# Dropa as duplicadas
dre.drop_duplicates(subset=None, keep="first", inplace=True)

# dre.count

# %%
# import DFC
dfc_01_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2010.csv')
dfc_02_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2011.csv')
dfc_03_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2012.csv')
dfc_04_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2013.csv')
dfc_05_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2014.csv')
dfc_06_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2015.csv')
dfc_07_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2016.csv')
dfc_08_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2017.csv')
dfc_09_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2018.csv')
dfc_10_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2019.csv')
dfc_11_csv = ('/content/drive/MyDrive/Bovespa/DFC/dfp_cia_aberta_DFC_MI_con_2020.csv')

# edicao e juncao do DFC
dfc_01 = pd.read_csv(dfc_01_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_02 = pd.read_csv(dfc_02_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_03 = pd.read_csv(dfc_03_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_04 = pd.read_csv(dfc_04_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_05 = pd.read_csv(dfc_05_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_06 = pd.read_csv(dfc_06_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_07 = pd.read_csv(dfc_07_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_08 = pd.read_csv(dfc_08_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_09 = pd.read_csv(dfc_09_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_10 = pd.read_csv(dfc_10_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')
dfc_11 = pd.read_csv(dfc_11_csv , decimal=',' ,  delimiter=';' , error_bad_lines=False , encoding='latin-1')

dfc = pd.concat([dfc_01 , dfc_02 , dfc_03 , dfc_04 , dfc_05 , dfc_06 , dfc_07 , dfc_08 , dfc_09 , dfc_10 , dfc_11], ignore_index=True)
dfc['VL_CONTA'] = dfc['VL_CONTA'].astype(str)
dfc['VL_CONTA'] = dfc['VL_CONTA'].str.replace('.0000000000', ' ')
# dfc['VL_CONTA'] = dfc['VL_CONTA'].astype(int)
dfc['DT_REFER'] = pd.to_datetime(dfc['DT_REFER'])
dfc['CD_CVM'] = dfc['CD_CVM'].astype(int)
dfc['DT_FIM_EXERC'] = pd.to_datetime(dfc['DT_FIM_EXERC'])

# Limpando as colunas do df
dfc = dfc.drop(['DT_REFER' ,
                'VERSAO' , 
                'GRUPO_DFP' , 
                'MOEDA' ,
                'ESCALA_MOEDA' , 
                'ORDEM_EXERC' , 
                'ST_CONTA_FIXA'] , axis=1)

# Modificando posicao das colunas
dfc = dfc[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'DT_FIM_EXERC' , 'CD_CONTA' , 'DS_CONTA' , 'VL_CONTA']]
dfc = dfc.sort_values(by=['DENOM_CIA' , 'CD_CONTA' ], ascending=True)

# Diminuia para minuscula
dfc['DS_CONTA'] = dfc['DS_CONTA'].str.lower()

# codigo limpa todos os pontos
dfc['DS_CONTA'] = dfc['DS_CONTA'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# Substitui CD_CONTA para padrao
dfc = (dfc.replace({'DS_CONTA' : replace_value_dfc} , regex=True).astype(str))

# Dropa as duplicadas
dfc.drop_duplicates(subset=None, keep="first", inplace=True)

# dfc.count

# %%
dfc['DS_CONTA'] = dfc['DS_CONTA'].str.split('dividendos_jcp').str[0]

# %%
denom_cia = "EQUATORIAL ENERGIA S.A."

busca = dfc[(dfc[dfc.columns[0]] == denom_cia)]
DataTable(busca)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DENOM_CIA</th>
#       <th>CD_CVM</th>
#       <th>CNPJ_CIA</th>
#       <th>DT_FIM_EXERC</th>
#       <th>CD_CONTA</th>
#       <th>DS_CONTA</th>
#       <th>VL_CONTA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6058</th>
#       <td>EQUATORIAL ENERGIA S.A.</td>
#       <td>20010</td>
#       <td>03.220.438/0001-73</td>
#       <td>2009-12-31</td>
#       <td>6.01</td>
#       <td>fco</td>
#       <td>179828</td>
#     </tr>
#     <tr>
#       <th>6059</th>
#       <td>EQUATORIAL ENERGIA S.A.</td>
#       <td>20010</td>
#       <td>03.220.438/0001-73</td>
#       <td>2010-12-31</td>
# ...

# %% [markdown]
# # **4 Junta todas DFP**

# %%
dfp = pd.concat([dre , bpa , bpp , dfc], ignore_index=True)
dfp = dfp.sort_values(["CD_CVM" , "CD_CONTA"], ascending = (True, True))
dfp = dfp.reset_index()

# Dropa duplicadas
dfp.drop_duplicates(subset=None, keep="first", inplace=True)
dfp = dfp.drop(dfp.columns[0],axis=1)

# %%
dfp.to_csv(path_or_buf='/content/drive/MyDrive/Bovespa/dfp.csv')

# %%
# df = dfp[['CD_CONTA' , 'DS_CONTA']]
# # codigo limpa todos os pontos
# df['DS_CONTA'] = df['DS_CONTA'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')


# df['DS_CONTA'] = df['DS_CONTA'].str.lower()
# df = df.drop_duplicates(['CD_CONTA' , 'DS_CONTA']).reset_index(drop=True)

# %% [markdown]
# # **Pesquisa Empresas**

# %%
pesq_comp = dfp[['DENOM_CIA' , 'CD_CVM']]
pesq_comp = pesq_comp.drop_duplicates(['DENOM_CIA'  , 'CD_CVM']).reset_index(drop=True)

# %%
DataTable(pesq_comp)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DENOM_CIA</th>
#       <th>CD_CVM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>PANATLANTICA S.A.</td>
#       <td>94</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>YARA BRASIL FERTILIZANTES</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BAHEMA EDUCAÇÃO S.A.</td>
#       <td>701</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BCO BRADESCO S.A.</td>
#       <td>906</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BCO BRASIL S.A.</td>
#       <td>1023</td>
#     </tr>
#     <tr>
#       <th>...</th>
# ...

# %% [markdown]
# # **5 Import CSV**

# %%
# leitura dfc
dfp_csv = ('/content/drive/MyDrive/Bovespa/dfp.csv')

# abre arquivo .csv
dfp_base = []
dfp_base = pd.read_csv(dfp_csv , delimiter=',' , error_bad_lines=False , encoding='latin-1')

# dropa a coluna 0
dfp_base = dfp_base.drop(dfp_base.columns[0],axis=1)
dfp_base.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# # **6 Separacao e busca por codigo**

# %%
# Cria as data 

data_2009 = '2009-12-31'
data_2010 = '2010-12-31'
data_2011 = '2011-12-31'
data_2012 = '2012-12-31'
data_2013 = '2013-12-31'
data_2014 = '2014-12-31'
data_2015 = '2015-12-31'
data_2016 = '2016-12-31'
data_2017 = '2017-12-31'
data_2018 = '2018-12-31'
data_2019 = '2019-12-31'
data_2020 = '2020-12-31'

# %%
###########################################################################
###########################################################################
####################### Busca por codigo
# Lista para separa na DFP
lst_busca = {'2.01.04' , '2.02.01' }

# Busca dentro da dfp
dfp_base = dfp_base[(dfp_base[dfp_base.columns[4]].isin(lst_busca))]

# 2.01.04	Empréstimos e Financiamentos Curto prazo
# 2.02.01	Empréstimos e Financiamentos Longo prazo

# Soma e agrupa as dividas
dfp_base = dfp_base.groupby(['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'DT_FIM_EXERC'])['VL_CONTA'].sum().reset_index()

# Converte para data
dfp_base['DT_FIM_EXERC'] = pd.to_datetime(dfp_base['DT_FIM_EXERC'])

# %%
# cria as lista de indicadores

# 2009
# escolhe apenas a data
ind_dfp_2009 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2009)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2009 = ind_dfp_2009.rename({'VL_CONTA': '2009'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2009 = ind_dfp_2009[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2009']]

# %%
# 2010
# escolhe apenas a data
ind_dfp_2010 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2010)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2010 = ind_dfp_2010.rename({'VL_CONTA': '2010'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2010 = ind_dfp_2010[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA'  , '2010']]

# %%
# 2011
# escolhe apenas a data
ind_dfp_2011 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2011)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2011 = ind_dfp_2011.rename({'VL_CONTA': '2011'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2011 = ind_dfp_2011[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2011']]

# %%
# 2012
# escolhe apenas a data
ind_dfp_2012 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2012)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2012 = ind_dfp_2012.rename({'VL_CONTA': '2012'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2012 = ind_dfp_2012[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2012']]

# %%
# 2013
# escolhe apenas a data
ind_dfp_2013 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2013)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2013 = ind_dfp_2013.rename({'VL_CONTA': '2013'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2013 = ind_dfp_2013[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA'  , '2013']]

# %%
# 2014
# escolhe apenas a data
ind_dfp_2014 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2014)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2014 = ind_dfp_2014.rename({'VL_CONTA': '2014'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2014 = ind_dfp_2014[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA'  , '2014']]

# %%
# 2015
# escolhe apenas a data
ind_dfp_2015 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2015)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2015 = ind_dfp_2015.rename({'VL_CONTA': '2015'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2015 = ind_dfp_2015[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2015']]

# %%
# 2016
# escolhe apenas a data
ind_dfp_2016 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2016)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2016 = ind_dfp_2016.rename({'VL_CONTA': '2016'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2016 = ind_dfp_2016[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA'  , '2016']]

# %%
# 2017
# escolhe apenas a data
ind_dfp_2017 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2017)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2017 = ind_dfp_2017.rename({'VL_CONTA': '2017'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2017 = ind_dfp_2017[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2017']]

# %%
# 2018
# escolhe apenas a data
ind_dfp_2018 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2018)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2018 = ind_dfp_2018.rename({'VL_CONTA': '2018'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2018 = ind_dfp_2018[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2018']]

# %%
# 2019
# escolhe apenas a data
ind_dfp_2019 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2019)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2019 = ind_dfp_2019.rename({'VL_CONTA': '2019'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2019 = ind_dfp_2019[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2019']]

# %%
# 2020
# escolhe apenas a data
ind_dfp_2020 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2020)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2020 = ind_dfp_2020.rename({'VL_CONTA': '2020'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2020 = ind_dfp_2020[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2020']]

# %% [markdown]
# #**6 Separacao e busca por nome**

# %%
# Cria as data 

data_2009 = '2009-12-31'
data_2010 = '2010-12-31'
data_2011 = '2011-12-31'
data_2012 = '2012-12-31'
data_2013 = '2013-12-31'
data_2014 = '2014-12-31'
data_2015 = '2015-12-31'
data_2016 = '2016-12-31'
data_2017 = '2017-12-31'
data_2018 = '2018-12-31'
data_2019 = '2019-12-31'
data_2020 = '2020-12-31'

# %%
###########################################################################
###########################################################################
######################### Busca por Nome
# Lista para separa na DFP


# Altera o que buscar
# lst_busca = {'ebit' , 'lucro_liq' }
lst_busca = {'aplicacoes_financ' ,
             'ativo_circ' , 
             'ativo_nao_circ' ,
             'ativo_total' , 
             'caixa_equival' , 
             'ebit' , 
             'fco' , 
             'lucro_liq' ,
             'passivo_circ' , 
             'passivo_nao_circ' , 
             'patrimonio_liquido' ,
             'receita_liq'}



# Busca dentro da dfp
dfp_base = dfp_base[(dfp_base[dfp_base.columns[5]].isin(lst_busca))]

# %%
# cria as lista de indicadores

# 2009
# escolhe apenas a data
ind_dfp_2009 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2009)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2009 = ind_dfp_2009.rename({'VL_CONTA': '2009'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2009 = ind_dfp_2009[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2009']]

# %%
# 2010
# escolhe apenas a data
ind_dfp_2010 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2010)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2010 = ind_dfp_2010.rename({'VL_CONTA': '2010'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2010 = ind_dfp_2010[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2010']]

# %%
# 2011
# escolhe apenas a data
ind_dfp_2011 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2011)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2011 = ind_dfp_2011.rename({'VL_CONTA': '2011'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2011 = ind_dfp_2011[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2011']]

# %%
# 2012
# escolhe apenas a data
ind_dfp_2012 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2012)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2012 = ind_dfp_2012.rename({'VL_CONTA': '2012'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2012 = ind_dfp_2012[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2012']]

# %%
# 2013
# escolhe apenas a data
ind_dfp_2013 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2013)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2013 = ind_dfp_2013.rename({'VL_CONTA': '2013'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2013 = ind_dfp_2013[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2013']]

# %%
# 2014
# escolhe apenas a data
ind_dfp_2014 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2014)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2014 = ind_dfp_2014.rename({'VL_CONTA': '2014'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2014 = ind_dfp_2014[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2014']]

# %%
# 2015
# escolhe apenas a data
ind_dfp_2015 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2015)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2015 = ind_dfp_2015.rename({'VL_CONTA': '2015'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2015 = ind_dfp_2015[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2015']]

# %%
# 2016
# escolhe apenas a data
ind_dfp_2016 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2016)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2016 = ind_dfp_2016.rename({'VL_CONTA': '2016'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2016 = ind_dfp_2016[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2016']]

# %%
# 2017
# escolhe apenas a data
ind_dfp_2017 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2017)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2017 = ind_dfp_2017.rename({'VL_CONTA': '2017'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2017 = ind_dfp_2017[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2017']]

# %%
# 2018
# escolhe apenas a data
ind_dfp_2018 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2018)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2018 = ind_dfp_2018.rename({'VL_CONTA': '2018'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2018 = ind_dfp_2018[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2018']]

# %%
# 2019
# escolhe apenas a data
ind_dfp_2019 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2019)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2019 = ind_dfp_2019.rename({'VL_CONTA': '2019'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2019 = ind_dfp_2019[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2019']]

# %%
# 2020
# escolhe apenas a data
ind_dfp_2020 = dfp_base[(dfp_base[dfp_base.columns[3]] == data_2020)]

# renomeia a coluna VL_CONTA para o ano  base
ind_dfp_2020 = ind_dfp_2020.rename({'VL_CONTA': '2020'}, axis=1)

# escolhe apenas as coluna selecionadas
ind_dfp_2020 = ind_dfp_2020[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'CD_CONTA' ,'DS_CONTA' , '2020']]

# %% [markdown]
# # **7 Juntando todas as DFP**

# %%
# 6 merge todos os indicadores

dfp_master =  pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(ind_dfp_2009 , ind_dfp_2010 , how="outer") , 
                                                                                                     ind_dfp_2011 , how="outer") ,
                                                                                                     ind_dfp_2012 , how="outer") , 
                                                                                                     ind_dfp_2013 , how="outer") ,
                                                                                                     ind_dfp_2014 , how="outer"),
                                                                                                     ind_dfp_2015 , how="outer"), 
                                                                                                     ind_dfp_2016 , how="outer"), 
                                                                                                     ind_dfp_2017 , how="outer"), 
                                                                                                     ind_dfp_2018 , how="outer"), 
                                                                                                     ind_dfp_2019 , how="outer"),
                                                                                                     ind_dfp_2020 , how="outer")

dfp_master.fillna(0 , inplace=True)
dfp_master.drop_duplicates(subset=None, keep="first", inplace=True) 



####### Metodo por nome
dfp_master = dfp_master[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , 'DS_CONTA' , 'CD_CONTA' , '2009' , '2010' , '2011' , '2012' , '2013' , '2014' , '2015' , '2016' , '2017' , '2018' , '2019' , '2020']]
dfp_master.drop_duplicates(subset=None, keep="first", inplace=True)
dfp_master = dfp_master.drop_duplicates(subset=['DENOM_CIA' , 'DS_CONTA'], keep='last')

####### Metodo por codigo
# dfp_master = dfp_master[['DENOM_CIA' , 'CD_CVM' , 'CNPJ_CIA' , '2009' , '2010' , '2011' , '2012' , '2013' , '2014' , '2015' , '2016' , '2017' , '2018' , '2019' , '2020']]
# dfp_master.drop_duplicates(subset=None, keep="first", inplace=True)

# %%
# Busca empresa
denom_cia = "EDP - ENERGIAS DO BRASIL S.A."

# busca =   dfp_base[(dfp_base[dfp_base.columns[0]] == denom_cia)]
busca =   dfp_master[(dfp_master[dfp_master.columns[0]] == denom_cia)]

# %%
DataTable(busca)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DENOM_CIA</th>
#       <th>CD_CVM</th>
#       <th>CNPJ_CIA</th>
#       <th>DS_CONTA</th>
#       <th>CD_CONTA</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8337</th>
#       <td>EDP - ENERGIAS DO BRASIL S.A.</td>
#       <td>19763</td>
#       <td>03.983.431/0001-03</td>
#       <td>ativo_total</td>
#       <td>1</td>
# ...

# %% [markdown]
# # **8 Import google planilhas**

# %%
# !pip install gspread
from google.colab import auth
import gspread
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

# !pip install gspread_dataframe
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# %%
# abre a planilha
planilha = gc.open('bd_bovespa')

# %%
# seleciona a pagina
importar = planilha.get_worksheet(0)

# %%
# salva os dados na pagina
set_with_dataframe(importar , dfp_master)

# %%
dfp_master
# Out:
#                                       DENOM_CIA  ...          2020
# 3                               BCO BRASIL S.A.  ...  1.693794e+09
# 7                               BCO BRASIL S.A.  ...  0.000000e+00
# 13                              BCO BRASIL S.A.  ...  0.000000e+00
# 15                              BCO BRASIL S.A.  ...  0.000000e+00
# 19                              BCO BRASIL S.A.  ...  0.000000e+00
# ...                                         ...  ...           ...
# 23915  FINANCEIRA ALFA S.A.- CRED FINANC E INVS  ...  1.005291e+06
# 23916                              FRAS-LE S.A.  ...  1.963700e+04
# 23917                   METALURGICA GERDAU S.A.  ...  0.000000e+00
# 23919                         BCO BRADESCO S.A.  ...  1.461174e+08
# 23920  DIMED S.A. DISTRIBUIDORA DE MEDICAMENTOS  ...  3.057010e+05
#
# [6867 rows x 17 columns]
